# %%
import os
import numpy as np

from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB

# %% [markdown]
# #### Il existe trois variante du Naïve Bayes :
# La probabilité de chaque caractéristique f-j sachant une classe c-i est estimée selon le type de ces valeurs: discrètes, binaires ou continues.
#
# - Loi multinomiale
# >- Lorsque les valeurs des caractéristiques sont discrètes, on utilise la loi multinomiale. Par exemple, la couleur des cheveux avec les valeurs: brun, auburn, châtain, roux, blond vénitien, blond et blanc.
# - Loi de Bernoulli
# >- Lorsque les valeurs des caractéristiques sont binaires, on utilise la loi de Bernoulli.
# - Loi normal
# > - Lorsque les valeurs des caractéristiques sont continues, on utilise la loi normale (loi gaussienne). Par exemple, le poids, le prix, etc.
#
# Pour plus de détaille voir :
# https://projeduc.github.io/intro_apprentissage_automatique/bayes.html

# %%
DATA_DIR = 'jeux_de_donnees/enron'
target_names = ['ham', 'spam']
# On crée une liste tout les noms des sous dossier dans le dossier eron
subfolders = ['enron%d' % i for i in range(1,7)]

#On crée une liste X qui contiendra tout les email
X = []
#On crée une liste y qui contiendra 1 si spam 0 sinon.
y = []

# %% [markdown]
# #### Lecture de tout les email contenues dans les dossier spam

# %%
for subfolder in subfolders:
    
    #On crée une liste de tout les fichier contenue le dossier spam de chaque sous-dossier
    spam_files = os.listdir(os.path.join(DATA_DIR, subfolder, 'spam'))
    for spam_file in spam_files:
        with open(os.path.join(DATA_DIR, subfolder, 'spam', spam_file), encoding='ascii', errors='ignore') as f:
            X.append(f.read())
            # On ajouter 1 à notre liste target pour chaque spam lu dans la liste data.
            y.append(1)
            
    ham_files = os.listdir(os.path.join(DATA_DIR, subfolder, 'ham'))
    for ham_file in ham_files:
        with open(os.path.join(DATA_DIR, subfolder, 'ham', ham_file), encoding='ascii', errors='ignore') as f:
            X.append(f.read())
            y.append(0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-659e673abf06> in <module>
#       2
#       3     #On crée une liste de tout les fichier contenue le dossier spam de chaque sous-dossier
# ----> 4     spam_files = os.listdir(os.path.join(DATA_DIR, subfolder, 'spam'))
#       5     for spam_file in spam_files:
#       6         with open(os.path.join(DATA_DIR, subfolder, 'spam', spam_file), encoding='ascii', errors='ignore') as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'jeux_de_donnees/enron/enron1/spam'

# %% [markdown]
# #### Partitionnement du jeu de données en jeu de test et d'entrainement.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# %% [markdown]
# #### On comment par convertir nos listes qui contiennent des chaine de caractère en valeur numérique :
# On va utiliser la focntion CountVectorizer() qui va :
# - construire un dictionnaire à partir de chacun des mot du texte
# - ramplacer chaque mit par son vecteur
# - et tout sommer pour nous

# %%
count_vec = CountVectorizer()
X_train_counts = count_vec.fit_transform(X_train)
print(X_train_counts)
# Out:
#   (0, 127701)	4
#   (0, 112094)	2
#   (0, 38375)	6
#   (0, 131577)	3
#   (0, 57844)	5
#   (0, 131645)	16
#   (0, 72061)	1
#   (0, 24498)	1
#   (0, 124556)	1
#   (0, 94455)	1
#   (0, 143255)	1
#   (0, 145440)	1
#   (0, 148230)	4
#   (0, 62395)	1
#   (0, 15936)	1
#   (0, 18021)	4
#   (0, 85805)	1
#   (0, 38237)	1
#   (0, 97446)	1
#   (0, 37831)	3
#   (0, 28189)	2
#   (0, 87742)	6
#   (0, 30359)	3
#   (0, 73202)	1
#   (0, 85638)	2
#   :	:
#   (30343, 61303)	1
#   (30343, 144678)	1
#   (30343, 20414)	1
#   (30343, 2902)	1
#   (30343, 2920)	1
#   (30343, 68284)	1
#   (30343, 76323)	3
#   (30343, 58893)	1
#   (30343, 36046)	1
#   (30343, 99341)	1
#   (30343, 88716)	1
#   (30343, 59699)	1
#   (30343, 66301)	1
#   (30343, 126122)	1
#   (30343, 42022)	1
#   (30343, 21231)	1
#   (30343, 32948)	1
#   (30343, 84216)	1
#   (30343, 36994)	2
#   (30343, 116385)	1
#   (30343, 71985)	1
#   (30343, 127334)	2
#   (30343, 748)	1
#   (30343, 89624)	1
#   (30343, 150002)	1

# %%
# Pour afficher chacun de mot du dictionnaire
# Les numéro après chaque forme un index unique
count_vec.vocabulary_
# Out:
# {'subject': 127701,
#  're': 112094,
#  'cornhusker': 38375,
#  'thanks': 131577,
#  'for': 57844,
#  'the': 131645,
#  'information': 72061,
#  'below': 24498,
#  'sometime': 124556,
#  'next': 94455,
#  'week': 143255,
#  'would': 145440,
#  'you': 148230,
#  'go': 62395,
#  'ahead': 15936,
#  'and': 18021,
#  'make': 85805,
#  'copy': 38237,
#  'of': 97446,
#  'contract': 37831,
#  'brief': 28189,
#  'me': 87742,
#  'can': 30359,
#  'interoffice': 73202,
#  'mail': 85638,
#  'it': 74433,
#  'to': 133238,
#  'at': 21015,
#  'eb': 48447,
#  '3703': 6253,
#  'kathy': 77707,
#  'benedict': 24581,
#  'daren': 41248,
#  'farmer': 55071,
#  '11': 1325,
#  '22': 3940,
#  '2000': 2904,
#  '42': 6896,
#  'am': 17314,
#  'katherine': 77695,
#  'hou': 68194,
#  'ect': 48752,
#  'cc': 31690,
#  'if': 69915,
#  'need': 93822,
#  've': 139710,
#  'got': 62802,
#  'that': 131596,
#  'lists': 82978,
#  'transport': 134452,
#  'cost': 38617,
#  'fuel': 59310,
#  'from': 59016,
#  'each': 48205,
#  'location': 83627,
#  'there': 131870,
#  'numerous': 96404,
#  'receipt': 112458,
#  'points': 105455,
#  'is': 74148,
#  'possible': 106106,
#  'we': 143034,
#  'may': 87182,
#  'purchase': 109266,
#  'extra': 54353,
#  'gas': 60324,
#  'plant': 104793,
#  'on': 98345,
#  'occasion': 97116,
#  'in': 71057,
#  'case': 31193,
#  'use': 138465,
#  'same': 118429,
#  'lone': 83874,
#  'star': 126304,
#  'other': 99700,
#  'pipes': 104426,
#  'also': 17143,
#  'any': 18872,
#  'expense': 54049,
#  'incur': 71460,
#  'deliver': 42690,
#  'will': 144298,
#  'be': 23876,
#  'passed': 101656,
#  'have': 65454,
#  'questions': 110714,
#  'let': 81982,
#  'know': 79136,
#  '23': 4114,
#  'hi': 66735,
#  'darrin': 41320,
#  'this': 132111,
#  'what': 143753,
#  'mark': 86554,
#  'mccoy': 87421,
#  'sent': 120706,
#  'about': 13678,
#  'deal': 41826,
#  'please': 104955,
#  'review': 115176,
#  'anything': 18902,
#  'else': 50204,
#  'rita': 115927,
#  'wynne': 146129,
#  'or': 99066,
#  'just': 77109,
#  'shoot': 121991,
#  'an': 17846,
#  'calling': 30179,
#  'back': 22492,
#  'happy': 65091,
#  'thanksgiving': 131580,
#  'forwarded': 58231,
#  'by': 29680,
#  '19': 2750,
#  'enron': 51309,
#  '08': 831,
#  '12': 1529,
#  'here': 66342,
#  'our': 99838,
#  'supply': 128524,
#  'comes': 35904,
#  'apache': 18999,
#  'williams': 144324,
#  'market': 86565,
#  'typicially': 135984,
#  'tenaska': 131000,
#  'iv': 74628,
#  'partners': 101589,
#  'down': 46710,
#  'brazos': 27902,
#  'utility': 138690,
#  'has': 65322,
#  'right': 115730,
#  'they': 131993,
#  'want': 142545,
#  'does': 46177,
#  'not': 95759,
#  'call': 30158,
#  'then': 131795,
#  'sell': 120497,
#  'off': 97487,
#  'whomever': 144036,
#  'get': 61303,
#  'flat': 57067,
#  'fee': 55557,
#  'per': 102694,
#  'mmbtu': 90386,
#  'whether': 143851,
#  'goes': 62485,
#  'knows': 79154,
#  'specifics': 125147,
#  'hope': 67930,
#  'helps': 66152,
#  'with': 144678,
#  '33396': 5680,
#  'weather': 143088,
#  'trading': 134140,
#  'prize': 107620,
#  'draw': 46994,
#  'dear': 41865,
#  'michelle': 89176,
#  'thank': 131569,
#  'registering': 113344,
#  'europe': 53175,
#  'sponsored': 125501,
#  'corporate': 38417,
#  'insurance': 72807,
#  'risk': 115888,
#  'pleased': 104958,
#  'your': 148297,
#  'name': 93073,
#  'been': 24144,
#  'drawn': 47010,
#  'as': 20414,
#  'one': 98389,
#  'winners': 144518,
#  'order': 99146,
#  'confirm': 37033,
#  'free': 58672,
#  'delegate': 42591,
#  'pass': 101641,
#  'event': 53308,
#  'respond': 114740,
#  'email': 50260,
#  'all': 16802,
#  'contact': 37647,
#  'details': 43605,
#  'register': 113340,
#  'send': 120620,
#  'out': 99899,
#  'booking': 27159,
#  'hotel': 68138,
#  'room': 116760,
#  'suggest': 128071,
#  'do': 46039,
#  'soon': 124667,
#  'are': 19844,
#  'quickly': 110768,
#  'running': 117614,
#  'space': 124917,
#  'going': 62527,
#  'unable': 136831,
#  'us': 138417,
#  'ticket': 132497,
#  'another': 18546,
#  'entrant': 51510,
#  'place': 104696,
#  'transferable': 134321,
#  'colleagues': 35599,
#  'so': 124108,
#  'feel': 55574,
#  'simply': 122723,
#  'look': 83945,
#  'forward': 58229,
#  'seeing': 120235,
#  'amsterdam': 17795,
#  'regards': 113285,
#  'allison': 16918,
#  'robertshaw': 116413,
#  'director': 44774,
#  '44': 7103,
#  '20': 2902,
#  '7375': 10459,
#  '7570': 10684,
#  '7511': 10613,
#  'arobertshaw': 20164,
#  'eyeforenergy': 54492,
#  'com': 35790,
#  'mentions': 88490,
#  'rise': 115872,
#  'fall': 54873,
#  'new': 94312,
#  'york': 148202,
#  'times': 132690,
#  '02': 369,
#  '01': 270,
#  'debacle': 41894,
#  'business': 29378,
#  'derivatives': 43241,
#  'danger': 41163,
#  'commentary': 36025,
#  'clout': 34860,
#  'won': 145121,
#  'sway': 128972,
#  'sec': 120032,
#  'afl': 15514,
#  'cio': 33981,
#  'amalgamated': 17328,
#  'bank': 23024,
#  'redirect': 112915,
#  'mission': 90049,
#  'newly': 94357,
#  'created': 39317,
#  'special': 125104,
#  'committee': 36100,
#  'outside': 100015,
#  'directors': 44784,
#  'must': 92473,
#  'adopt': 14991,
#  'independent': 71524,
#  'role': 116634,
#  'pr': 106583,
#  'newswire': 94427,
#  'ceo': 32192,
#  'sees': 120275,
#  'validation': 139215,
#  'co': 35121,
#  'bandwidth': 22979,
#  'model': 90592,
#  'dow': 46695,
#  'jones': 76426,
#  'energy': 50979,
#  'service': 120945,
#  'usa': 138418,
#  'shares': 121511,
#  'plunge': 105135,
#  'after': 15577,
#  'section': 120120,
#  '2001': 2920,
#  'page': 100822,
#  '24': 4264,
#  'column': 35779,
#  'company': 36224,
#  'earlier': 48290,
#  'year': 147659,
#  'most': 91423,
#  'companies': 36215,
#  'loved': 84255,
#  'problems': 107708,
#  'californians': 30139,
#  'resented': 114540,
#  'huge': 68708,
#  'profits': 107995,
#  'during': 47782,
#  'their': 131739,
#  'crisis': 39553,
#  'democrats': 42834,
#  'washington': 142709,
#  'raised': 111419,
#  'influence': 71972,
#  'within': 144710,
#  'white': 143941,
#  'house': 68220,
#  'cozy': 39008,
#  'relationship': 113651,
#  'between': 25089,
#  'chairman': 32531,
#  'kenneth': 78076,
#  'lay': 81111,
#  'vice': 140559,
#  'president': 107171,
#  'dick': 44243,
#  'cheney': 33076,
#  'nobody': 95279,
#  'seemed': 120253,
#  'better': 25069,
#  'positioned': 106052,
#  'thrive': 132321,
#  'bush': 29351,
#  'presidency': 107170,
#  'than': 131565,
#  'houston': 68253,
#  'based': 23384,
#  'apostle': 19173,
#  'deregulation': 43215,
#  'wall': 142441,
#  'street': 127273,
#  'was': 142690,
#  'impressed': 70944,
#  'strategy': 127226,
#  'swooping': 129171,
#  'into': 73362,
#  'formerly': 58093,
#  'regulated': 113424,
#  'markets': 86607,
#  'broker': 28422,
#  'contracts': 37843,
#  'natural': 93344,
#  'electricity': 49891,
#  'unused': 137975,
#  'telecom': 130752,
#  'celebrated': 31969,
#  'paragon': 101261,
#  'american': 17521,
#  'ingenuity': 72168,
#  'stodgy': 126967,
#  'pipeline': 104420,
#  'had': 64591,
#  'reinvented': 113554,
#  'itself': 74549,
#  'high': 66833,
#  'tech': 130552,
#  'clearinghouse': 34527,
#  'ever': 53326,
#  'expanding': 53973,
#  'roster': 116893,
#  'push': 109372,
#  'force': 57876,
#  'utilities': 138684,
#  'internet': 73169,
#  'age': 15663,
#  'its': 74542,
#  'online': 98479,
#  'systems': 129479,
#  'seemingly': 120256,
#  'handsome': 64975,
#  'profit': 107978,
#  'became': 24009,
#  'epic': 51805,
#  'tale': 129845,
#  'dot': 46601,
#  'revolution': 115243,
#  'now': 95948,
#  'appears': 19213,
#  'more': 91222,
#  'cautionary': 31557,
#  'envy': 51663,
#  'crashed': 39235,
#  'along': 17071,
#  'stock': 126907,
#  'price': 107351,
#  'serious': 120891,
#  'emerge': 50454,
#  'bookkeeping': 27167,
#  'disclosed': 44950,
#  'month': 91082,
#  'billion': 25649,
#  'value': 139304,
#  'vanished': 139390,
#  'result': 114872,
#  'controversial': 37938,
#  'entered': 51412,
#  'private': 107577,
#  'partnerships': 101591,
#  'run': 117592,
#  'chief': 33238,
#  'financial': 56506,
#  'officer': 97562,
#  'andrew': 18119,
#  'fastow': 55162,
#  'alarming': 16431,
#  'reluctance': 113772,
#  'shed': 121615,
#  'light': 82525,
#  'management': 86027,
#  'wheeling': 143800,
#  'dealing': 41838,
#  'related': 113643,
#  'party': 101602,
#  'transactions': 134269,
#  'accountants': 14076,
#  'them': 131772,
#  'fraught': 58607,
#  'conflicts': 37073,
#  'interest': 73049,
#  'though': 132235,
#  'much': 92031,
#  'remains': 113786,
#  'learned': 81420,
#  'these': 131935,
#  'scope': 119533,
#  'lack': 80330,
#  'transparency': 134439,
#  'effect': 49153,
#  'own': 100442,
#  'hedge': 65920,
#  'fund': 59451,
#  'assume': 20864,
#  'some': 124527,
#  'mask': 86825,
#  'losses': 84134,
#  'complex': 36419,
#  'extent': 54317,
#  'which': 143861,
#  'insiders': 72588,
#  'profited': 107988,
#  'yet': 147765,
#  'clear': 34514,
#  'scrambled': 119609,
#  'dampen': 41114,
#  'concerns': 36730,
#  'acknowledging': 14275,
#  'credibility': 39354,
#  'problem': 107701,
#  'while': 143880,
#  'insisting': 72612,
#  'health': 65777,
#  'core': 38306,
#  'businesses': 29381,
#  'wednesday': 143237,
#  'brought': 28518,
#  'william': 144323,
#  'powers': 106396,
#  'dean': 41856,
#  'university': 137568,
#  'texas': 131374,
#  'school': 119357,
#  'law': 81058,
#  'securities': 120163,
#  'exchange': 53673,
#  'commission': 36075,
#  'launched': 80975,
#  'formal': 58052,
#  'investigation': 73572,
#  'mr': 91743,
#  'forced': 57878,
#  'resign': 114615,
#  'following': 57686,
#  'jeffrey': 75504,
#  'skilling': 123185,
#  'man': 86017,
#  'credited': 39366,
#  'driving': 47184,
#  'cutting': 40494,
#  'edge': 48849,
#  'door': 46481,
#  'former': 58091,
#  'admirers': 14945,
#  'mindful': 89685,
#  'recent': 112486,
#  'scandals': 119106,
#  'involving': 73694,
#  'profile': 107966,
#  'doctoring': 46108,
#  'earnings': 48314,
#  'spectacular': 125172,
#  'collapse': 35569,
#  'long': 83883,
#  'term': 131165,
#  'capital': 30653,
#  '1998': 2896,
#  'alarmed': 16429,
#  'carole': 31012,
#  'coale': 35144,
#  'prudential': 108689,
#  'summed': 128211,
#  'up': 138080,
#  'prevailing': 107285,
#  'sentiment': 120721,
#  'when': 143818,
#  'she': 121594,
#  'told': 133396,
#  'bottom': 27393,
#  'line': 82719,
#  'really': 112238,
#  'difficult': 44409,
#  'recommend': 112671,
#  'investment': 73592,
#  'disclose': 44949,
#  'facts': 54720,
#  'analysts': 17927,
#  'well': 143400,
#  'media': 87883,
#  'entirely': 51472,
#  'blameless': 26194,
#  'did': 44288,
#  'mention': 88485,
#  'albeit': 16455,
#  'passing': 101665,
#  'troubling': 135034,
#  'deals': 41848,
#  'early': 48295,
#  'march': 86392,
#  'but': 29430,
#  'few': 55886,
#  'bothered': 27370,
#  'raise': 111418,
#  'time': 132659,
#  'revenues': 115140,
#  'were': 143495,
#  'soaring': 124124,
#  'harvey': 65314,
#  'pitt': 104527,
#  'commissioner': 36079,
#  'pursue': 109352,
#  'inquiry': 72507,
#  'aggressively': 15742,
#  'assure': 20875,
#  'investors': 73599,
#  'he': 65698,
#  'vigilant': 140728,
#  'his': 67103,
#  'predecessor': 106804,
#  'arthur': 20320,
#  'levitt': 82105,
#  'protecting': 108465,
#  'integrity': 72881,
#  'indeed': 71490,
#  'even': 53300,
#  'cleared': 34519,
#  'wrongdoing': 145706,
#  'regains': 113264,
#  'past': 101696,
#  'luster': 84893,
#  'might': 89389,
#  'preaches': 106715,
#  'merits': 88617,
#  'self': 120460,
#  'regulating': 113426,
#  'marketplaces': 86603,
#  'reminded': 113848,
#  'strong': 127396,
#  'regulator': 113430,
#  'copyright': 38244,
#  'inc': 71157,
#  'rights': 115742,
#  'reserved': 114556,
#  'november': 95929,
#  'finance': 56488,
#  'byzantine': 29780,
#  'shattered': 121560,
#  'outfit': 99931,
#  'executives': 53792,
#  'flying': 57457,
#  'corp': 38403,
#  'ene': 50935,
#  'never': 94291,
#  'overly': 100216,
#  'concerned': 36726,
#  'how': 68284,
#  'rest': 114790,
#  'world': 145331,
#  'viewed': 140698,
#  'practices': 106605,
#  'california': 30136,
#  'attorney': 21317,
#  'general': 60922,
#  'court': 38864,
#  'collect': 35604,
#  'documents': 46141,
#  'industrywide': 71758,
#  'fixing': 56878,
#  'analyst': 17925,
#  'challenged': 32564,
#  'conference': 36936,
#  'produce': 107840,
#  'balance': 22778,
#  'sheet': 121636,
#  'called': 30170,
#  'him': 66975,
#  'ass': 20702,
#  'still': 126799,
#  'worried': 145385,
#  'gone': 62622,
#  'too': 133564,
#  'far': 55025,
#  'two': 135814,
#  'set': 121018,
#  '1999': 2901,
#  'buy': 29512,
#  'assets': 20774,
#  'investments': 73594,
#  'acting': 14417,
#  'manager': 86033,
#  'position': 106050,
#  'personally': 103056,
#  'benefit': 24608,
#  'potential': 106245,
#  'conflict': 37069,
#  'backlash': 22541,
#  'overwhelming': 100350,
#  'internally': 73144,
#  'everybody': 53349,
#  'said': 118207,
#  'good': 62644,
#  'idea': 69716,
#  'says': 118983,
#  'source': 124826,
#  'close': 34814,
#  'no': 95256,
#  'could': 38715,
#  'predicted': 106823,
#  'such': 127963,
#  'jaw': 75225,
#  'dropping': 47243,
#  'outcome': 99915,
#  'nation': 93303,
#  'largest': 80762,
#  'innovative': 72436,
#  'trader': 134122,
#  'since': 122765,
#  'oct': 97214,
#  '16': 2319,
#  'revealed': 115108,
#  '35': 5934,
#  'million': 89589,
#  'charge': 32734,
#  'reflect': 113162,
#  'those': 132232,
#  'knock': 79109,
#  'shareholders': 121504,
#  'equity': 52051,
#  'plunged': 105136,
#  '60': 8925,
#  'highly': 66865,
#  'ballyhooed': 22872,
#  'speed': 125214,
#  'communications': 36157,
#  'capacity': 30619,
#  'crippled': 39537,
#  'industry': 71752,
#  'meltdown': 88316,
#  'calamitous': 30044,
#  'foray': 57852,
#  'water': 142785,
#  'azurix': 22399,
#  'already': 17126,
#  'least': 81448,
#  '574': 8650,
#  'write': 145668,
#  'offs': 97613,
#  'bad': 22612,
#  'bets': 25061,
#  'expensive': 54059,
#  'ljm': 83166,
#  'shock': 121949,
#  'lurking': 84881,
#  'many': 86304,
#  'aren': 19869,
#  'sticking': 126754,
#  'around': 20178,
#  'find': 56546,
#  'think': 132072,
#  'disclosure': 44953,
#  'engineering': 51082,
#  'killed': 78511,
#  'team': 130505,
#  'richard': 115585,
#  'giesen': 61612,
#  'who': 143999,
#  'manages': 86040,
#  'munder': 92301,
#  'power': 106351,
#  'plus': 105146,
#  'dumped': 47661,
#  'ago': 15797,
#  'financing': 56522,
#  'vehicles': 139775,
#  'used': 138472,
#  'over': 100100,
#  'years': 147671,
#  'oil': 97868,
#  'producers': 107844,
#  'sources': 124829,
#  'say': 118962,
#  'particular': 101553,
#  'interconnected': 73004,
#  'entities': 51477,
#  'whitewing': 143970,
#  'osprey': 99604,
#  'atlantic': 21145,
#  'trust': 135153,
#  'marlin': 86651,
#  'way': 142874,
#  'longer': 83889,
#  'central': 32148,
#  'freeing': 58703,
#  'credit': 39359,
#  'ventures': 139921,
#  'like': 82573,
#  'broadband': 28354,
#  'table': 129590,
#  'entice': 51462,
#  'institutional': 72735,
#  'pension': 102600,
#  'funds': 59481,
#  'insurers': 72815,
#  'promised': 108168,
#  'kick': 78428,
#  'asset': 20771,
#  'sales': 118295,
#  'weren': 143499,
#  'enough': 51260,
#  'cover': 38915,
#  'debt': 41960,
#  'mandatory': 86078,
#  'half': 64742,
#  'dozen': 46808,
#  'others': 99706,
#  'industries': 71750,
#  'including': 71271,
#  'el': 49788,
#  'paso': 101637,
#  'epg': 51779,
#  'dominion': 46374,
#  'standard': 126234,
#  'poor': 105791,
#  'todd': 133299,
#  'shipman': 121849,
#  'particularly': 101558,
#  'unique': 137503,
#  'board': 26771,
#  'banker': 23032,
#  'specializing': 125127,
#  'worst': 145404,
#  'considers': 37411,
#  'unlikely': 137604,
#  'hook': 67888,
#  'mean': 87774,
#  'diluting': 44574,
#  '25': 4433,
#  'today': 133289,
#  'prices': 107366,
#  'john': 76323,
#  'olson': 98195,
#  'sanders': 118527,
#  'morris': 91327,
#  'harris': 65264,
#  'smhg': 123765,
#  'figures': 56309,
#  'dilution': 44575,
#  'likely': 82581,
#  'included': 71266,
#  'ratio': 111776,
#  'climb': 34692,
#  '54': 8289,
#  '49': 7667,
#  'end': 50865,
#  'june': 77018,
#  'change': 32635,
#  'pressure': 107203,
#  'rating': 111771,
#  'grade': 63025,
#  'hit': 67172,
#  'different': 44393,
#  'kind': 78571,
#  'animal': 18343,
#  'according': 14062,
#  'familiar': 54936,
#  'arrangements': 20221,
#  'bought': 27427,
#  'booked': 27155,
#  'gains': 59946,
#  'involved': 73688,
#  'hedging': 65929,
#  'supposed': 128545,
#  'reduce': 112973,
#  'volatility': 141543,
#  'stakes': 126177,
#  'consumers': 37623,
#  'terminated': 131182,
#  'september': 120782,
#  'took': 133573,
#  'immediate': 70634,
#  'question': 110703,
#  'stick': 126749,
#  'first': 56744,
#  'show': 122124,
#  'successful': 127928,
#  'platform': 104851,
#  'trades': 134127,
#  'everything': 53365,
#  'reassure': 112327,
#  'scrambling': 119612,
#  'shore': 122029,
#  'liquidity': 82900,
#  'tapped': 130066,
#  'lines': 82754,
#  'trying': 135185,
#  'arrange': 20213,
#  'seen': 120262,
#  'signs': 122540,
#  'massive': 86868,
#  'customer': 40424,
#  'defections': 42314,
#  'drastically': 46989,
#  'worsened': 145397,
#  'terms': 131197,
#  'rival': 115956,
#  'traders': 134125,
#  'wary': 142687,
#  'certainly': 32270,
#  'taken': 129810,
#  'closer': 34821,
#  'last': 80842,
#  '10': 990,
#  'days': 41559,
#  'continue': 37803,
#  'manage': 86021,
#  'doing': 46232,
#  'usual': 138596,
#  'keith': 77991,
#  'stamm': 126213,
#  'aquila': 19588,
#  'ila': 70318,
#  'speeding': 125222,
#  'train': 134195,
#  'battered': 23564,
#  'agencies': 15678,
#  'considering': 37410,
#  'further': 59573,
#  'downgrades': 46722,
#  'rapidly': 111650,
#  'uncertainty': 136975,
#  'future': 59628,
#  'reduced': 112974,
#  'appetite': 19238,
#  'wants': 142558,
#  'speculate': 125198,
#  'direction': 44759,
#  'likelihood': 82580,
#  'survival': 128720,
#  'salesperson': 118305,
#  'front': 59043,
#  'calm': 30196,
#  'face': 54652,
#  'tougher': 133848,
#  'task': 130153,
#  'restoring': 114831,
#  'hovering': 68278,
#  '14': 1970,
#  '90': 12030,
#  'august': 21506,
#  'believe': 24419,
#  'takeover': 129814,
#  'target': 130089,
#  'likes': 82586,
#  'ge': 60678,
#  'royal': 117051,
#  'dutch': 47821,
#  'shell': 121665,
#  'group': 63628,
#  'rd': 112027,
#  'both': 27365,
#  'declined': 42110,
#  'comment': 36023,
#  'talked': 129865,
#  'mergers': 88591,
#  'strategic': 127211,
#  'alliances': 16904,
#  'among': 17680,
#  'take': 129800,
#  'easy': 48395,
#  'pull': 109140,
#  'through': 132342,
#  'suspect': 128751,
#  'humbler': 68787,
#  'averse': 21982,
#  'once': 98360,
#  'believed': 24420,
#  'expand': 53968,
#  'logistics': 83760,
#  'empire': 50613,
#  'manner': 86216,
#  'commodities': 36113,
#  'advertising': 15167,
#  'steel': 126544,
#  'scale': 119080,
#  'grandiose': 63110,
#  'visions': 141041,
#  'something': 124553,
#  'applaud': 19256,
#  'should': 122095,
#  'focus': 57587,
#  'strengths': 127297,
#  'adams': 14580,
#  'senior': 120657,
#  'banc': 22929,
#  'america': 17519,
#  'major': 85782,
#  'shareholder': 121503,
#  'less': 81955,
#  'exciting': 53698,
#  'cowboys': 38948,
#  'hoped': 67931,
#  'roam': 116369,
#  'stephanie': 126643,
#  'anderson': 18054,
#  'forest': 57968,
#  'wendy': 143457,
#  'zellner': 149215,
#  'dallas': 41059,
#  'heather': 65857,
#  'timmons': 132724,
#  'lately': 80873,
#  'owners': 100451,
#  'bonds': 27077,
#  'loans': 83558,
#  'struggling': 127463,
#  'understand': 137180,
#  'exposed': 54214,
#  'risks': 115915,
#  'didn': 44297,
#  'before': 24189,
#  'fuller': 59392,
#  'picture': 104118,
#  'entanglements': 51397,
#  'begins': 24229,
#  'worry': 145392,
#  'default': 42292,
#  'swaps': 128952,
#  'known': 79151,
#  'cdss': 31854,
#  'short': 122041,
#  'marketspeak': 86608,
#  'pay': 101965,
#  'premium': 106969,
#  'coverage': 38916,
#  'reimburses': 113507,
#  'cds': 31850,
#  'existed': 53909,
#  'only': 98520,
#  'growing': 63656,
#  'fast': 55138,
#  'goldman': 62568,
#  'sachs': 118045,
#  'gs': 63753,
#  'estimate': 52804,
#  'trillion': 134845,
#  'covered': 38920,
#  'surprisingly': 128683,
#  'big': 25490,
#  'banks': 23060,
#  'hefty': 65980,
#  'sheets': 121641,
#  'morgan': 91263,
#  'chase': 32825,
#  'jpm': 76617,
#  'merrill': 88653,
#  'lynch': 85131,
#  'mer': 88522,
#  'deutsche': 43715,
#  'db': 41585,
#  'dominate': 46354,
#  'however': 68298,
#  'player': 104891,
#  'significant': 122521,
#  'isn': 74272,
#  'competitors': 36337,
#  'although': 17203,
#  'issued': 74368,
#  '500': 7735,
#  '700': 10059,
#  'worth': 145406,
#  'ambitious': 17431,
#  'plans': 104788,
#  'offer': 97511,
#  'don': 46385,
#  ...}

# %%
X_train_counts.shape
# Out:
# (30344, 150271)

# %%
print(X_train_counts[0])
# Out:
#   (0, 127701)	4
#   (0, 112094)	2
#   (0, 38375)	6
#   (0, 131577)	3
#   (0, 57844)	5
#   (0, 131645)	16
#   (0, 72061)	1
#   (0, 24498)	1
#   (0, 124556)	1
#   (0, 94455)	1
#   (0, 143255)	1
#   (0, 145440)	1
#   (0, 148230)	4
#   (0, 62395)	1
#   (0, 15936)	1
#   (0, 18021)	4
#   (0, 85805)	1
#   (0, 38237)	1
#   (0, 97446)	1
#   (0, 37831)	3
#   (0, 28189)	2
#   (0, 87742)	6
#   (0, 30359)	3
#   (0, 73202)	1
#   (0, 85638)	2
#   :	:
#   (0, 138690)	1
#   (0, 65322)	1
#   (0, 115730)	1
#   (0, 131993)	1
#   (0, 142545)	1
#   (0, 46177)	1
#   (0, 95759)	2
#   (0, 30158)	2
#   (0, 131795)	1
#   (0, 120497)	1
#   (0, 97487)	1
#   (0, 144036)	1
#   (0, 61303)	1
#   (0, 57067)	1
#   (0, 55557)	1
#   (0, 102694)	1
#   (0, 90386)	1
#   (0, 143851)	1
#   (0, 62485)	1
#   (0, 79154)	1
#   (0, 125147)	1
#   (0, 67930)	1
#   (0, 66152)	1
#   (0, 144678)	1
#   (0, 5680)	1

# %% [markdown]
# #### Maintenant on applique la transformation tf.idf

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf[0])
# Out:
#   (0, 148230)	0.04925615977636903
#   (0, 146129)	0.054838542384100596
#   (0, 145440)	0.0218316452812981
#   (0, 144678)	0.015302664968140907
#   (0, 144324)	0.04295413468191148
#   (0, 144298)	0.03343754852118188
#   (0, 144036)	0.06633062480383585
#   (0, 143851)	0.03947324750044667
#   (0, 143753)	0.04857273537151021
#   (0, 143255)	0.02807640270763269
#   (0, 143034)	0.09173731372098101
#   (0, 142545)	0.026154764895255762
#   (0, 139710)	0.03302194493116669
#   (0, 138690)	0.047230727079474295
#   (0, 138465)	0.027378522750878764
#   (0, 135984)	0.08232914692317359
#   (0, 134452)	0.13779467948452526
#   (0, 133238)	0.12868190192185952
#   (0, 132111)	0.05821955416507975
#   (0, 131993)	0.025069738688245937
#   (0, 131870)	0.04781462436445775
#   (0, 131795)	0.02960803426195387
#   (0, 131645)	0.1758907711293936
#   (0, 131596)	0.06446105959625699
#   (0, 131580)	0.058929862165533434
#   :	:
#   (0, 27902)	0.13318301207900518
#   (0, 24581)	0.3451523318091459
#   (0, 24498)	0.028386501918252257
#   (0, 23876)	0.015380508419703539
#   (0, 22492)	0.028858540677081494
#   (0, 21015)	0.01688508012323294
#   (0, 18999)	0.058409578006151715
#   (0, 18902)	0.036563679057003765
#   (0, 18872)	0.05945686924652025
#   (0, 18021)	0.04770390461523434
#   (0, 17846)	0.020253595377548964
#   (0, 17314)	0.08745098884898296
#   (0, 17143)	0.024125626109102384
#   (0, 15936)	0.04356237744041294
#   (0, 13678)	0.09288144284181002
#   (0, 6896)	0.04076752587211511
#   (0, 6253)	0.07422834841984845
#   (0, 5680)	0.06583177673979512
#   (0, 4114)	0.03396699332739113
#   (0, 3940)	0.13513048645488407
#   (0, 2904)	0.09997968397167815
#   (0, 2750)	0.03196854617479531
#   (0, 1529)	0.02587401903921487
#   (0, 1325)	0.18705205863397809
#   (0, 831)	0.03325760159841649

# %% [markdown]
# #### Je lance l'entrainement avec le BernoulliNB

# %%
model = BernoulliNB()
model.fit(X_train_tfidf, y_train)
# Out:
# BernoulliNB()

# %%
X_test_counts = count_vec.transform(X_test)
X_test_tfidf = tfidf_transformer.transform(X_test_counts)
y_pred = model.predict(X_test_tfidf)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.9878410438908659

# %%
model = MultinomialNB()
model.fit(X_train_tfidf, y_train)

X_test_counts = count_vec.transform(X_test)
X_test_tfidf = tfidf_transformer.transform(X_test_counts)
y_pred = model.predict(X_test_tfidf)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.9884341637010676

# %% [markdown]
# #### Je définis mon modèle avec un pipline et je lance l'apprantissage

# %%
text_model = Pipeline([('count_vec', CountVectorizer()), 
                     ('tfidf_transformer', TfidfTransformer()),
                     ('text_model', SGDClassifier(tol=None, loss='log'))])

text_model.fit(X_train, y_train)
y_pred = text_model.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9798339264531435
