# %%
import numpy as np

world_alcohol = np.genfromtxt("world_alcohol.csv",delimiter=",", dtype="U75", skip_header=1)
print(world_alcohol)
# Out:
# [['1986' 'Western Pacific' 'Viet Nam' 'Wine' '0']
#  ['1986' 'Americas' 'Uruguay' 'Other' '0.5']
#  ['1985' 'Africa' "Cte d'Ivoire" 'Wine' '1.62']
#  ...
#  ['1986' 'Europe' 'Switzerland' 'Spirits' '2.54']
#  ['1987' 'Western Pacific' 'Papua New Guinea' 'Other' '0']
#  ['1986' 'Africa' 'Swaziland' 'Other' '5.15']]

# %%
countries_is_canada = world_alcohol[:,2] == "canada" #quels sont les lignes qui contiennent
print(countries_is_canada)
# Out:
# [False False False ... False False False]

# %%
# une fois on sait qu'elles st les lignes je les reselect
countries_canada = world_alcohol[world_alcohol[:,2] == "Canada"] #quels sont les lignes qui contiennent
print(countries_canada)
print()
print(countries_canada.shape)
# shape == compte nbre ligne,ligne col
# Out:
# [['1984' 'Americas' 'Canada' 'Spirits' '3.35']
#  ['1989' 'Americas' 'Canada' 'Wine' '1.27']
#  ['1984' 'Americas' 'Canada' 'Beer' '5']
#  ['1985' 'Americas' 'Canada' 'Beer' '4.94']
#  ['1987' 'Americas' 'Canada' 'Wine' '1.3']
#  ['1987' 'Americas' 'Canada' 'Beer' '4.83']
#  ['1986' 'Americas' 'Canada' 'Other' '']
#  ['1986' 'Americas' 'Canada' 'Spirits' '3.11']
#  ['1985' 'Americas' 'Canada' 'Spirits' '3.21']
#  ['1985' 'Americas' 'Canada' 'Other' '']
#  ['1986' 'Americas' 'Canada' 'Beer' '4.87']
#  ['1984' 'Americas' 'Canada' 'Wine' '1.24']
#  ['1989' 'Americas' 'Canada' 'Spirits' '2.91']
#  ['1984' 'Americas' 'Canada' 'Other' '']
#  ['1985' 'Americas' 'Canada' 'Wine' '1.29']
#  ['1987' 'Americas' 'Canada' 'Spirits' '2.99']
#  ['1989' 'Americas' 'Canada' 'Beer' '4.82']
#  ['1989' 'Americas' 'Canada' 'Other' '']
#  ['1986' 'Americas' 'Canada' 'Wine' '1.33']
#  ['1987' 'Americas' 'Canada' 'Other' '']]
#
# (20, 5)

# %%
countries_is_algeria = world_alcohol[:,2] == "Algeria" #quels sont les lignes qui contiennent
countries_algeria = world_alcohol[countries_is_algeria]
print(countries_algeria.shape)
# Out:
# (20, 5)

# %%
countries_is_algeria = world_alcohol[:,0] == "1984" #quels sont les lignes qui contiennent
countries_algeria = world_alcohol[countries_is_algeria]
print(countries_algeria.shape)#selectionne
# Out:
# (646, 5)

# %%
# comparaison avec plus conditions
# & et                  #fichier   #lign,col            +                   ou c'est =
is_algeria_and_1986 = (world_alcohol[:,2] == "Algeria") & (world_alcohol[:,0] == "1986")
rows_with_algeria_and_1986 = world_alcohol[is_algeria_and_1986] # je mets dans rows_with
print(rows_with_algeria_and_1986)
# Out:
# [['1986' 'Africa' 'Algeria' 'Wine' '0.1']
#  ['1986' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1986' 'Africa' 'Algeria' 'Beer' '0.18']
#  ['1986' 'Africa' 'Algeria' 'Other' '0']]

# %%
# | or 

is_algeria_and_1986 = (world_alcohol[:,2] == "Algeria") | (world_alcohol[:,0] == "Canada")
rows_with_algeria_and_1986 = world_alcohol[is_algeria_and_1986] # je mets dans rows_with_alg..
print(rows_with_algeria_and_1986)
# Out:
# [['1984' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1987' 'Africa' 'Algeria' 'Beer' '0.17']
#  ['1987' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1986' 'Africa' 'Algeria' 'Wine' '0.1']
#  ['1984' 'Africa' 'Algeria' 'Other' '0']
#  ['1989' 'Africa' 'Algeria' 'Beer' '0.16']
#  ['1989' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1989' 'Africa' 'Algeria' 'Wine' '0.23']
#  ['1986' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1984' 'Africa' 'Algeria' 'Wine' '0.12']
#  ['1985' 'Africa' 'Algeria' 'Beer' '0.19']
#  ['1985' 'Africa' 'Algeria' 'Other' '0']
#  ['1986' 'Africa' 'Algeria' 'Beer' '0.18']
#  ['1985' 'Africa' 'Algeria' 'Wine' '0.11']
#  ['1986' 'Africa' 'Algeria' 'Other' '0']
#  ['1989' 'Africa' 'Algeria' 'Other' '0']
#  ['1987' 'Africa' 'Algeria' 'Other' '0']
#  ['1984' 'Africa' 'Algeria' 'Beer' '0.2']
#  ['1985' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1987' 'Africa' 'Algeria' 'Wine' '0.1']]

# %%
world_alcohol_2 = world_alcohol.copy() # faire une copy

# %%
print(world_alcohol_2[:,0])
# Out:
# ['1986' '1986' '1985' ... '1986' '1987' '1986']

# %%
print(world_alcohol_2[world_alcohol_2[:,0] == '1986']) # affiche mon info ligne col
# Out:
# [['1986' 'Western Pacific' 'Viet Nam' 'Wine' '0']
#  ['1986' 'Americas' 'Uruguay' 'Other' '0.5']
#  ['1986' 'Americas' 'Colombia' 'Beer' '4.27']
#  ...
#  ['1986' 'Western Pacific' 'Fiji' 'Spirits' '0.05']
#  ['1986' 'Europe' 'Switzerland' 'Spirits' '2.54']
#  ['1986' 'Africa' 'Swaziland' 'Other' '5.15']]

# %%
print(world_alcohol_2[:,0][world_alcohol_2[:,0] == '1986'])
# Out:
# ['1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986']

# %%
masque = (world_alcohol_2[:,0] == '1986')
world_alcohol_2[:,0] [masque] = '2018' # remplace 1 valeur

# %%
print(world_alcohol_2)
# Out:
# [['2018' 'Western Pacific' 'Viet Nam' 'Wine' '0']
#  ['2018' 'Americas' 'Uruguay' 'Other' '0.5']
#  ['1985' 'Africa' "Cte d'Ivoire" 'Wine' '1.62']
#  ...
#  ['2018' 'Europe' 'Switzerland' 'Spirits' '2.54']
#  ['1987' 'Western Pacific' 'Papua New Guinea' 'Other' '0']
#  ['2018' 'Africa' 'Swaziland' 'Other' '5.15']]

# %%
world_alcohol_2[:,3][world_alcohol_2[:,3] == 'Wine'] = 'beer' # modifie

# %%
print(world_alcohol_2)
# Out:
# [['2018' 'Western Pacific' 'Viet Nam' 'beer' '0']
#  ['2018' 'Americas' 'Uruguay' 'Other' '0.5']
#  ['1985' 'Africa' "Cte d'Ivoire" 'beer' '1.62']
#  ...
#  ['2018' 'Europe' 'Switzerland' 'Spirits' '2.54']
#  ['1987' 'Western Pacific' 'Papua New Guinea' 'Other' '0']
#  ['2018' 'Africa' 'Swaziland' 'Other' '5.15']]

# %%
is_value_empty = (world_alcohol [:,4] == '') #lig,col
print(is_value_empty) # quand c'est vide
# Out:
# [False False False ... False False False]

# %%
# on rajoute ---------------pour ttes les col vide on raj 0
world_alcohol[is_value_empty, 4] = '0'
print(world_alcohol)
# Out:
# [['1986' 'Western Pacific' 'Viet Nam' 'Wine' '0']
#  ['1986' 'Americas' 'Uruguay' 'Other' '0.5']
#  ['1985' 'Africa' "Cte d'Ivoire" 'Wine' '1.62']
#  ...
#  ['1986' 'Europe' 'Switzerland' 'Spirits' '2.54']
#  ['1987' 'Western Pacific' 'Papua New Guinea' 'Other' '0']
#  ['1986' 'Africa' 'Swaziland' 'Other' '5.15']]

# %%
alcohol_consumption = world_alcohol[:,4] # je recup
alcohol_consumption = alcohol_consumption.astype(float) # pour convertir
print(alcohol_consumption)
# Out:
# [0.   0.5  1.62 ... 2.54 0.   5.15]

# %%
#pour tt calculer
total_alcohol = alcohol_consumption.sum()
average_alcohol = alcohol_consumption.mean()

# %%
print(total_alcohol)
# Out:
# 3908.96

# %%
print(average_alcohol)
# Out:
# 1.2001719373656738

# %%
is_canada_and_1987 = (world_alcohol[:,2] == "Canada") & (world_alcohol[:,0] == "1987")# ! espace entre guillemet !
rows_with_canada_and_1987 = world_alcohol[is_canada_and_1987] # ! tjrs rapel ton dossier / tu veux ca ds ca
alcohol_consumption_canada1987 = rows_with_canada_and_1987[:,4] # pour comparer
alcohol_consumption_canada1987 = alcohol_consumption_canada1987.astype(float)
print(alcohol_consumption_canada1987.sum())
print(alcohol_consumption_canada1987.mean())
# Out:
# 9.120000000000001
# 2.2800000000000002

# %%
is_Americas_and_Beer = (world_alcohol[:,1] == "Americas") & (world_alcohol[:,3] == "Beer")
Americas_and_Beer = world_alcohol[is_Americas_and_Beer]
alcohol_consumption_Americas_and_Beer = Americas_and_Beer[:,4]
alcohol_consumption_Americas_and_Beer = alcohol_consumption_Americas_and_Beer.astype(float)
print(alcohol_consumption_Americas_and_Beer.sum())
print(alcohol_consumption_Americas_and_Beer.mean())
# Out:
# 310.02
# 2.0001290322580645

# %%
totals = ()

is_year = world_alcohol[:,0] == "1989"
year = world_alcohol[is_year]
contries = world_alcohol[:,2]
countrie= contries


for i in countrie:
    country_consumpt=countrie
    country_consumpt=year
    
    #print(country_consumpt[0,-4])
    
    is_value_empty = (country_consumpt[0,-4] == '') #lig,col
    #print(is_value_empty) # quand c'est vide
    
    # on rajoute ---------------pour ttes les col vide on raj 0
    world_alcohol[is_value_empty, -4] = '0'
    #print(world_alcohol)
    
    truche = is_year.astype(float)
    
    total_alcohol = truche.sum()
    average_alcohol = truche.mean()
    
    #print(total_alcohol)
    #print(average_alcohol)
    total=[countrie,average_alcohol]
    print(total)
# Out:
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# ...
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]
# [array(['Viet Nam', 'Uruguay', "Cte d'Ivoire", ..., 'Switzerland',
#        'Papua New Guinea', 'Swaziland'], dtype='<U75'), 0.20110531163647527]

# %%
dic_pays = {}
annee = '1989'

list_pays = world_alcohol[:,2][world_alcohol[:,0]==annee]

for i in list pays :
    if i not in dic_pays :
        dic_pays[i] = i
max_consomme = 0
name_pays = ""

for p,v in dic_pays.items() :
    vpay =  world_alcohol[( world_alcohol[:,2]==p & (world_alcohol[:,0]==anne)]
    tab_pay = vpay[:,4]
    tab_pay = tab_pay.astype(float)
    dic_pays[p] = tab.pay.sum()
    if(tab_pay.sum() > max_consomme):
        max_consomme = tab_pay.sum()
        name_pays= p
print(dic_pays)
print(name_pays, 'a', max_consomme)
# Out:
# ['Guatemala' 'Seychelles' 'Costa Rica' 'Mauritius' 'Zimbabwe' 'Suriname'
#  'Croatia' 'Syrian Arab Republic' 'Bolivia (Plurinational State of)'
#  'Somalia' 'Namibia' 'Uganda' 'Afghanistan' 'Jamaica' 'Finland' 'Iraq'
#  'Malawi' 'Bulgaria' 'Nicaragua' 'Central African Republic' 'Afghanistan'
#  'Burundi' 'Sweden' 'Greece' 'Kyrgyzstan' 'Belgium' 'Angola'
#  'Burkina Faso' 'Czech Republic' 'United Arab Emirates' 'Peru'
#  'Trinidad and Tobago' 'Guyana' 'Bahrain' 'Benin' 'Liberia' 'Viet Nam'
#  'Belarus' 'Syrian Arab Republic' 'Swaziland' 'France'
#  'United States of America' 'Cabo Verde' 'Trinidad and Tobago'
#  'Saudi Arabia' 'Poland' 'Senegal' 'Bulgaria' 'Slovenia' 'Hungary'
#  'Iran (Islamic Republic of)' 'Lesotho' 'Gabon' 'Comoros' 'Malawi' 'Italy'
#  'Denmark' 'Nicaragua' 'Canada' 'Zambia' 'Peru' 'Botswana' 'Kuwait'
#  'Russian Federation' 'New Zealand' 'Uruguay'
#  'Bolivia (Plurinational State of)' 'Fiji' 'Liberia' 'Israel'
#  "Cte d'Ivoire" 'Suriname' 'Spain' 'South Africa' 'Morocco'
#  'Venezuela (Bolivarian Republic of)' 'Egypt' 'Zambia' 'Ethiopia' 'Bhutan'
#  'Chile' 'Kyrgyzstan' 'Bolivia (Plurinational State of)' 'Cambodia'
#  'Greece' 'Mali' 'Nepal' 'Jamaica' 'Kiribati' 'Dominican Republic'
#  'Vanuatu' 'Solomon Islands' 'Croatia' 'Uruguay' 'Libya' 'Saudi Arabia'
#  'Suriname' 'Costa Rica' 'Ukraine' 'Zambia' 'Denmark' 'Vanuatu' 'Eritrea'
#  'Switzerland' 'Dominican Republic' 'Mexico' 'Portugal' 'Benin' 'Ukraine'
#  'El Salvador' 'Philippines' 'Netherlands' 'Mozambique' 'Angola' 'Togo'
#  "Democratic People's Republic of Korea" 'Portugal' 'Cuba' 'Netherlands'
#  'Nepal' 'Togo' 'Singapore' 'Slovenia' 'Lithuania' 'Peru' 'Nicaragua'
#  'Ecuador' 'Swaziland' 'Sweden' 'Singapore' 'Malaysia' 'Bulgaria' 'Niger'
#  'Trinidad and Tobago' 'Cambodia' 'Democratic Republic of the Congo'
#  'Australia' 'Finland' 'Peru' 'Cyprus' 'Mali' 'Burkina Faso' 'Iraq'
#  'Antigua and Barbuda' 'Syrian Arab Republic' 'Antigua and Barbuda'
#  'Ecuador' 'Pakistan' 'Colombia' 'Saint Lucia' 'Hungary' 'France'
#  "Democratic People's Republic of Korea" 'Saint Lucia' 'Malaysia' 'Brazil'
#  'Morocco' 'Bahrain' 'Algeria' 'Israel' 'Malta' 'Greece'
#  "Lao People's Democratic Republic" 'Croatia' 'Turkey' 'Bhutan' 'Ghana'
#  'Mauritania' 'Cameroon' 'Czech Republic' 'Bahamas' 'Gabon' 'Djibouti'
#  'Equatorial Guinea' 'Oman' 'Algeria' 'Kuwait' 'Niger' 'Comoros'
#  'Micronesia (Federated States of)' 'Burundi' 'Myanmar' 'Cabo Verde'
#  'Guyana' 'Qatar' 'Rwanda' 'Botswana' 'Mongolia' 'Comoros' 'Myanmar'
#  'Zimbabwe' 'Spain' 'Latvia' 'Venezuela (Bolivarian Republic of)' 'Kenya'
#  'Bahamas' 'Cyprus' 'Iran (Islamic Republic of)' 'Senegal'
#  'Democratic Republic of the Congo' 'Pakistan' 'Algeria' 'Djibouti'
#  'Saint Kitts and Nevis' 'Japan' 'Ethiopia' 'Iceland' 'Papua New Guinea'
#  'Libya' 'Guinea-Bissau' 'Belize' 'Gabon' 'Mexico'
#  'United Republic of Tanzania' 'Philippines' 'Afghanistan' 'Burkina Faso'
#  "Democratic People's Republic of Korea" 'Paraguay' 'Guyana' 'Thailand'
#  'Saudi Arabia' 'Belgium' 'Jamaica' 'Rwanda' 'Israel' 'Egypt' 'Fiji'
#  "Lao People's Democratic Republic" 'Saint Lucia' 'Saint Kitts and Nevis'
#  'Russian Federation' 'Zimbabwe' 'United Republic of Tanzania' 'Tunisia'
#  'Bulgaria' 'Qatar' 'Eritrea' 'Antigua and Barbuda' 'Botswana' 'Ethiopia'
#  'United Kingdom of Great Britain and Northern Ireland' 'Sweden' 'Lebanon'
#  'United Republic of Tanzania' 'Luxembourg' 'Iceland' 'Albania'
#  'Mozambique' 'Latvia' 'Senegal' 'Belgium' 'Chile'
#  'United States of America' 'Togo' 'Cabo Verde' 'Bangladesh' 'Lesotho'
#  'Sudan' 'Congo' "Democratic People's Republic of Korea" 'Malta' 'Cuba'
#  'Indonesia' 'Sierra Leone' 'Burundi' 'Guinea' 'Panama' 'Bangladesh'
#  'Bahamas' 'Honduras' 'Kiribati' 'Samoa' 'Portugal' 'Brunei Darussalam'
#  'Cyprus' 'Jamaica' 'France' 'Equatorial Guinea' 'Saint Lucia' 'Zambia'
#  'Guatemala' 'Panama' 'Germany' 'Japan' 'Papua New Guinea' "Cte d'Ivoire"
#  'Pakistan' 'Guinea' 'Poland' 'Yemen' 'Portugal' 'Mongolia' 'Chad'
#  'Bahrain' 'Mali' 'Thailand' 'Swaziland' 'Sri Lanka' 'South Africa'
#  'Ghana' 'Belize' 'Honduras' 'Saint Kitts and Nevis' 'Switzerland'
#  'Republic of Korea' 'Rwanda' 'Mauritius' 'Central African Republic'
#  'Somalia' 'Trinidad and Tobago' 'Sierra Leone' 'Afghanistan'
#  'Guinea-Bissau' 'Viet Nam' 'Gabon' 'Poland' 'Chad' 'Germany' 'Sudan'
#  'Uruguay' 'Mauritania' 'Lesotho' 'Brunei Darussalam' 'Thailand'
#  'Paraguay' 'Cambodia' 'Solomon Islands' 'Iran (Islamic Republic of)'
#  'Sao Tome and Principe' "Lao People's Democratic Republic" 'Slovakia'
#  'Brazil' 'Singapore' 'Denmark' 'United States of America'
#  'Democratic Republic of the Congo' 'Haiti' 'Oman' 'Sierra Leone' 'Jordan'
#  'Bhutan' 'Congo' 'Madagascar' 'Sudan' 'Slovakia' 'Nicaragua' 'Iraq'
#  'Austria' 'Paraguay' 'Samoa' 'Malaysia' 'Ukraine' 'Namibia' 'Vanuatu'
#  'Cameroon' 'Luxembourg' 'Ethiopia' 'Cabo Verde' 'Mozambique' 'Australia'
#  'Yemen' 'Vanuatu' 'Slovenia' 'Norway' 'Republic of Korea' 'Benin'
#  'Sierra Leone' 'Burkina Faso' 'Belarus' 'Thailand' 'Panama'
#  'United Arab Emirates' 'Argentina' 'Congo' 'Honduras' 'Japan' 'Japan'
#  'Rwanda' 'Myanmar' 'Cameroon' 'Greece' 'Singapore' 'Guyana' 'Angola'
#  'Panama' 'Australia' 'Sweden' 'Lithuania' 'Samoa' 'Sao Tome and Principe'
#  'Uganda' 'Somalia' 'Bhutan' 'Madagascar' 'Mexico' 'Cameroon' 'Albania'
#  'Spain' 'Slovakia' 'Democratic Republic of the Congo' 'Germany'
#  'Russian Federation' 'Haiti' 'Romania' 'Romania' 'Norway' 'Lithuania'
#  'Egypt' 'Malawi' 'Costa Rica' 'Central African Republic' 'Germany'
#  'South Africa' 'Nepal' 'Suriname' 'Cyprus' 'Kuwait' 'Costa Rica' 'China'
#  'Comoros' 'El Salvador' 'El Salvador' 'Austria' 'Indonesia' 'Bahamas'
#  'Nigeria' 'Brazil' 'Kiribati' 'Kyrgyzstan' 'Belarus' 'Pakistan' 'Libya'
#  'Lithuania' 'Namibia' 'Bahrain' 'India'
#  'United Kingdom of Great Britain and Northern Ireland' 'Uruguay'
#  'Venezuela (Bolivarian Republic of)' 'Ghana' 'Finland' 'Botswana'
#  'Brunei Darussalam' 'Argentina' "Cte d'Ivoire" 'Mauritius'
#  'United Arab Emirates' 'Ireland' 'Eritrea' 'Equatorial Guinea'
#  'Republic of Korea' 'Guinea' 'Viet Nam' 'Guinea-Bissau' 'Djibouti'
#  'Kenya' 'Lesotho' 'Iran (Islamic Republic of)' 'Brunei Darussalam'
#  'Guatemala' 'El Salvador' 'Fiji' 'Equatorial Guinea' 'Turkey' 'Albania'
#  'Viet Nam' 'Venezuela (Bolivarian Republic of)' 'Sao Tome and Principe'
#  'Ecuador' 'Colombia' 'Lebanon' 'Nigeria' 'Cuba' 'Nigeria' 'Honduras'
#  'Mauritania' 'Kyrgyzstan' 'India' 'Togo' 'Guinea-Bissau' 'Ireland'
#  'Kuwait' 'Romania' 'Madagascar' 'Dominican Republic' 'Papua New Guinea'
#  'Paraguay' 'Lebanon' 'Tunisia' 'Italy' 'Micronesia (Federated States of)'
#  'Finland' 'China' 'Republic of Korea' 'Malta' 'Eritrea' 'Philippines'
#  'Niger' 'Sri Lanka' 'France' 'Oman' 'Niger' 'New Zealand' 'Italy'
#  'Swaziland' 'Liberia' "Cte d'Ivoire" 'Australia' 'Belgium'
#  'Papua New Guinea' 'Algeria' 'Sri Lanka' 'Luxembourg' 'Uganda' 'Gambia'
#  'Tunisia' 'Mexico' 'Kenya' 'Russian Federation' 'Ghana' 'Nepal' 'Norway'
#  'Kiribati' 'Saint Kitts and Nevis' 'Canada' 'Belarus' 'Italy' 'Sudan'
#  'Qatar' 'Gambia' 'Iceland' 'Kenya' 'India' 'Chile' 'Liberia'
#  'United States of America' 'Guatemala'
#  'United Kingdom of Great Britain and Northern Ireland' 'Slovakia'
#  'Netherlands' 'Senegal' 'Fiji' 'Mali' 'Sri Lanka' 'Slovenia' 'Cambodia'
#  'Guinea' 'Jordan' 'Indonesia' 'Libya' 'Czech Republic' 'Morocco' 'Brazil'
#  'India' 'Philippines' 'Ukraine' 'Oman' 'Nigeria' 'Turkey'
#  'Dominican Republic' 'Hungary' 'Malawi' 'United Arab Emirates'
#  'Switzerland' 'Belize' 'Burundi' 'Israel' 'Namibia' 'Uganda' 'Cuba'
#  'Hungary' 'Ecuador' 'Romania' 'Micronesia (Federated States of)'
#  'Zimbabwe' 'Jordan' 'Benin' 'Belize' 'Chad' 'Tunisia' 'Gambia'
#  'Luxembourg' 'Switzerland' 'Malta' 'Antigua and Barbuda' 'Spain' 'China'
#  'Solomon Islands' 'Indonesia' 'Ireland' 'Yemen' 'Iceland' 'Albania'
#  'Central African Republic' 'Qatar' 'Colombia' 'Chad' 'Netherlands'
#  'New Zealand' 'Iraq' 'Jordan' 'Djibouti' 'Ireland' 'Norway' 'Haiti'
#  'Seychelles' 'Bangladesh' 'China' 'Austria' 'Latvia' 'Somalia'
#  'Bangladesh' 'Argentina'
#  'United Kingdom of Great Britain and Northern Ireland'
#  "Lao People's Democratic Republic" 'Argentina' 'Mozambique'
#  'Sao Tome and Principe' 'United Republic of Tanzania' 'Czech Republic'
#  'Angola' 'Saudi Arabia' 'Egypt' 'Syrian Arab Republic' 'Colombia'
#  'New Zealand' 'Malaysia' 'Croatia' 'Mauritania' 'Mongolia'
#  'Micronesia (Federated States of)' 'Mongolia' 'Chile' 'Lebanon' 'Latvia'
#  'Canada' 'Congo' 'Canada' 'Solomon Islands' 'Mauritius' 'Gambia' 'Haiti'
#  'Yemen' 'Austria' 'Denmark' 'Seychelles' 'Samoa' 'Myanmar' 'South Africa'
#  'Bolivia (Plurinational State of)' 'Madagascar' 'Morocco' 'Poland'
#  'Turkey']
