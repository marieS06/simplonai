# %%
import pandas as pd
import numpy as np

ar= np.array([[1.1,2,3.3,4], [2.7,10,5.4,7],[5.3,9,1.5,15]])
df= pd.DataFrame(ar, index = ['a1','a2','a3'], columns = ['A','B','C','D'])
df
# Out:
#       A     B    C     D
# a1  1.1   2.0  3.3   4.0
# a2  2.7  10.0  5.4   7.0
# a3  5.3   9.0  1.5  15.0

# %%
#DATAFRAME AVEC CREER UN DICTIONNAIRE
dic= {'A': [1.1,2.7,5.3], 'B': [2,10,9], 'C':[3.3,5.4,1.5],'D': ['a','b','c']}
df= pd.DataFrame(dic, index = ['a1','a2','a3'])
df
# Out:
#       A   B    C  D
# a1  1.1   2  3.3  a
# a2  2.7  10  5.4  b
# a3  5.3   9  1.5  c

# %%
# Lire un fichier en csv
import pandas as pd

food_info = pd.read_csv("food_info.csv")
print(type(food_info))
print()
print(food_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
food_info
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
#selectionner une ligne

#assigner la 100 e ligne du dataframe (loc)
# ligne, index
row_100 = food_info.loc[99]
print(type(row_100))
print()
row_100
# Out:
# <class 'pandas.core.series.Series'>
# NDB_No                                  1111
# Shrt_Desc          MILK SHAKES THICK VANILLA
# Water_(g)                              74.45
# Energ_Kcal                               112
# Protein_(g)                             3.86
# Lipid_Tot_(g)                           3.03
# Ash_(g)                                 0.91
# Carbohydrt_(g)                         17.75
# Fiber_TD_(g)                               0
# Sugar_Tot_(g)                          17.75
# Calcium_(mg)                             146
# Iron_(mg)                                0.1
# Magnesium_(mg)                            12
# Phosphorus_(mg)                          115
# Potassium_(mg)                           183
# Sodium_(mg)                               95
# Zinc_(mg)                               0.39
# Copper_(mg)                            0.051
# Manganese_(mg)                         0.014
# Selenium_(mcg)                           2.3
# ...

# %%
#selectionner les 5 derniere ligne | je pars de -5 a -1
num_rows = food_info.shape[0]
print(num_rows)
print(num_rows-5)
print(num_rows-1)
# Out:
# 8618
# 8613
# 8617

# %%
last_rows = food_info.loc[num_rows - 5 : num_rows - 1]
last_rows
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 8613          25.10    13.40            0.00           0.0            0.0
# 8614           0.84     2.97            5.41           0.0            0.0
# 8615           0.00     0.86           73.14           0.0           73.2
# 8616           1.40     1.30            2.00           0.0            0.0
# 8617           0.50     1.20            0.00           0.0            0.0
#
# ...

# %%
#select une col plutot qune ligne 
#creer un nouvel objet
#pour travailler avec des lignes .loc
protein = food_info["Protein_(g)"]
cholesterol = food_info["Cholestrl_(mg)"]

# %%
print(type(protein))
print()
print(protein)
# Out:
# <class 'pandas.core.series.Series'>
#
# 0        0.85
# 1        0.85
# 2        0.28
# 3       21.40
# 4       23.24
#         ...
# 8613    18.50
# 8614    20.54
# 8615     0.00
# 8616    16.10
# 8617    19.80
# Name: Protein_(g), Length: 8618, dtype: float64

# %%
print(cholesterol)
# Out:
# 0       215.0
# 1       219.0
# 2       256.0
# 3        75.0
# 4        94.0
#         ...
# 8613     95.0
# 8614     41.0
# 8615      0.0
# 8616     50.0
# 8617     50.0
# Name: Cholestrl_(mg), Length: 8618, dtype: float64

# %%
#selectionner plusieurs colonne
#fournir une liste qui va contenir les col que je veux selectionner
selenium_thiamin = food_info[['Shrt_Desc','Thiamin_(mg)']]
print(type(selenium_thiamin))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
col_names = food_info.columns.tolist()#permet de convertir en liste
gram_columns=[]#destine a recevoir ts le noms de col g

for c in col_names: # parcourir ma liste qui contient mes noms de col si ce termine par un g ( meth enswitch)
    if c.endswith("(g)"):#si renvoie true ou false .(str). append a ma liste
        gram_columns.append(c)
        
gram_df = food_info[gram_columns]

gram_df
# Out:
#       Water_(g)  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0         15.87         0.85          81.11     2.11            0.06
# 1         15.87         0.85          81.11     2.11            0.06
# 2          0.24         0.28          99.48     0.00            0.00
# 3         42.41        21.40          28.74     5.11            2.34
# 4         41.11        23.24          29.68     3.18            2.79
# ...         ...          ...            ...      ...             ...
# 8613      43.00        18.50          25.10    13.40            0.00
# 8614      70.25        20.54           0.84     2.97            5.41
# 8615      26.00         0.00           0.00     0.86           73.14
# 8616      79.20        16.10           1.40     1.30            2.00
# 8617      78.50        19.80           0.50     1.20            0.00
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)
# ...

# %%
print(type(food_info.columns.tolist()))

print(food_info)
# Out:
# <class 'list'>
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
import pandas as pd

titanic_survival = pd.read_csv("titanic_survival.csv")

print(titanic_survival)
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
#assigner à la valeur age la colonne des ages, utiliser pandas is.null sur la var age pour creer une serie de valeur true ou false
#utiliser la serie resultante pour selectionner seulement les el de la col age 
#assigner le nbre de val de age null

# %%
age=titanic_survival['age']
age_null=age.isnull()
#print(age_null)
age_null_count=sum(age_null)
print(age_null_count)
# Out:
# 264

# %%
# age_is_null = pd.isnull(titanic_survival["age"])
# good_ages = titanic_survival["age"][ages_is_null == False]#recup lage ou il est pas manquant ou ==false
# mean_age = sum(good_ages) / len(good_ages) #recup
# print(mean_age)

# %%
mean_fare = titanic_survival["fare"].mean() # calculer la moyenne plus facilement
print(mean_fare)
# Out:
# 33.29547928134572

# %%
# calculer les statistiques de prix

fares_by_class={}
passenger=titanic_survival['pclass']
passenger_classes=[1,2,3]

for index in passenger_classes:
        truc = (titanic_survival["pclass"] == index)
        pclass_rows = titanic_survival[truc]
        fare=pclass_rows['fare']
        value=fare.mean()
        fares_by_class[index]=value
print(fares_by_class)
# Out:
# {1: 87.50899164086687, 2: 21.1791963898917, 3: 13.302888700564957}

# %%
# fares_by_class= {}
# passenger_classes=[1,2,3]


# for this_class in passenger_classes:
#     is_class = (titanic_survival["pclass"] == this_class)
#     pclass_rows = titanic_survival[is_class]
#     pclass_fares = pclass_rows['fare']
#     fare_for_class = pclass_fares.mean()
#     fares_by_class[this_class] = fare_for_class 
    
# print(fares_by_class)

# %%
g = titanic_survival.groupby('fare')
print(g)

# %%
d=titanic_survival["pclass"] == 1
de=titanic_survival[d]
f=titanic_survival["name"] == 'Allen'
fe=titanic_survival[f]
print(fe,de)
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []      pclass  survived                                             name  \
# 0       1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1       1.0       1.0                   Allison, Master. Hudson Trevor
# 2       1.0       0.0                     Allison, Miss. Helen Loraine
# 3       1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 318     1.0       0.0           Williams-Lambert, Mr. Fletcher Fellows
# 319     1.0       1.0                        Wilson, Miss. Helen Alice
# 320     1.0       1.0                                Woolner, Mr. Hugh
# 321     1.0       0.0                               Wright, Mr. George
# ...

# %%
# methode pivot de table calcul de colonne 
# pivot pour calculer la moyenne voir channel.... value quelle est la col sur laquelle on veut calcule la moyenne
passenger_age = titanic_survival.pivot_table(index="pclass", values="age")
print(passenger_age)
# Out:
#               age
# pclass
# 1.0     39.159918
# 2.0     29.506705
# 3.0     24.816367

# %%
# nbre moyenne de survivant par class
passenger_survival = titanic_survival.pivot_table(index="pclass", values="survived")
print(passenger_survival)
# Out:
#         survived
# pclass
# 1.0     0.619195
# 2.0     0.429603
# 3.0     0.255289

# %%
#aggfunc je veux avoir la somme ds values je pe lui fournir 1 liste de col il faut import numpy pour les ()
#preciser la ( pour la somme)...
import numpy as np

port_stats = titanic_survival.pivot_table(index="embarked", value=["fare","survived"], aggfunc=np.sum)

print(port_stats)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-288-3842b04f178d> in <module>
#       3 import numpy as np
#       4
# ----> 5 port_stats = titanic_survival.pivot_table(index="embarked", value=["fare","survived"], aggfunc=np.sum)
#       6
#       7 print(port_stats)
#
# TypeError: pivot_table() got an unexpected keyword argument 'value'

# %%
# axis = 0 pour supprimer les lignes et axis = 1 pour supprimer les colonnes
#- Supprimer toutes les lignes de titanic_survival pour lesquelles les colonnes "age" ou "sex" ont des valeurs manquantes et assigner le résultat à la variable new_titanic_survival.
#- Comparer le nombre de lignes qu'il reste avec l'attribut shape.
new_titanic_survival = titanic_survival.dropna(axis=0, subset=["age","sex"])
new_titanic_survival
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301     3.0       0.0                             Youseff, Mr. Gerious
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# loc les etiquette des indices et des col
# iloc seulement pour les index precise [0:10] lignes de 0 à 10
# seulement la cinquieme ligne .iloc[4]

first_ten_rows = new_titanic_survival.iloc[0:10]
row_position_fifth = new_titanic_survival.iloc[4]
row_index_25 = new_titanic_survival.loc[25]

# %%
#loc ligne, l'etiquette de la  colonne÷ligne,col
#5premiere 3 premiere col iloc [0:5:,0:3] 
#index de colonne
#Assigner les 10 premières lignes de new_titanic_survival à la variable first_ten_rows.
#- Assigner la 5e ligne de new_titanic_survival à la variable row_position-fifth.
#- Assigner la ligne dont l'intitulé d'index est 25 pour new_titanic_survival à la variable row_index_25.

row_index_1100_age = new_titanic_survival.loc[1100,"age"]
row_index_25_survived = new_titanic_survival.loc[25,"survived"]
five_rows_three_cols = new_titanic_survival.iloc[0:5,0:3]

# %%
print(type(row_index_25_survived))
# Out:
# <class 'numpy.float64'>

# %%
#reset_index(drop=true) sinon conserve l'ancien index
titanic_reindexed = new_titanic_survival.reset_index(drop=True)
titanic_reindexed.iloc[0:5,0:3]
#methode parenthese parcequ'elle apartient a reset index
# Out:
#    pclass  survived                                             name
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1     1.0       1.0                   Allison, Master. Hudson Trevor
# 2     1.0       0.0                     Allison, Miss. Helen Loraine
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)

# %%
#stoke ds la null la col
def null_count(column):
    column_null = pd.isnull(column)
    null = column[column_null]
    return len(null)

# %%
# Ecrire une fonction qui compte le nombre d'éléments manquants d'un objet Series.
#- Utiliser la méthode DataFrame.apply() pour appliquer votre fonction sur titanic_survival.
#- Assigner le résultat  à la variable column_null_count.
#- Afficher le résultat.
#mettre en aplication avec apply
column_null_count = titanic_survival.apply(null_count)
print(column_null_count)
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
#réer une fonction qui retourne la chaine de caractères "minor" pour quelqu'un de moins de 18 ans,
#"adult" si son age est supérieur ou égal à 18 et "unknown" si la valeur est manquante.
#- utiliser cette fonction avec la méthode apply() 
#pour trouver l'intitulé correct pour chaque pssager du dataframe titanic_survival.
#- Assigner le résultat à la variable age_labels.
#- Afficher le résultat.def null_count(column):
def coun(indice):
    indice=1
    for indice in agees:
        age_label = titanic_survival.iloc[0:5:,0:5] 
    if indice < 18:
        print('minor')
    if indice > 18:
        print('adult')
    else:
        print('unknown')
    indice=agees   
    return indice

# %%
age_labels = titanic_survival[['pclass', 'age']].apply(coun, axis = 1)
print(age_labels)
# Out:
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# ...

# %%
def coun(row):
    age = row["age"]
    
    if pd.isnull(age):
        return "unknow"
    if age < 18:
        return 'minor'
    else:
        return 'adult'

# %%
age_labels = titanic_survival.apply(coun, axis = 1)
print(age_labels)
# Out:
# 0        adult
# 1        minor
# 2        minor
# 3        adult
# 4        adult
#          ...
# 1305    unknow
# 1306     adult
# 1307     adult
# 1308     adult
# 1309    unknow
# Length: 1310, dtype: object

# %%
def ma_ligne(ligne):
    if ligne["age"] < 18:
        return "minor"
    elif ligne["age"] >= 18:
        return "adult"
    else:
        return 'unknown'
liste_age = titanic_survival.apply(ma_ligne, axis=1)
print(liste_age)
# Out:
# 0         adult
# 1         minor
# 2         minor
# 3         adult
# 4         adult
#          ...
# 1305    unknown
# 1306      adult
# 1307      adult
# 1308      adult
# 1309    unknown
# Length: 1310, dtype: object

# %%
print(titanic_survival)
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
def generate_age_label(row):
    age = row["age"]
    
    if pd.isnull (age):
        return "unknow"
    elif age < 18:
        return "minor"
    else:
        return "adult"

# %%
    
age_labels = titanic_survival.apply(generate_age_label, axis = 1)
print(type(age_labels))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# - Ajouter la colonne "age_labels" au dataframe titanic_survival contenant la variable age_labels qu'on a créé précédement.
# - Créer une table pivot qui calcule la moyenne de chance de survie (colonne "survived") pour chaque groupe d'âge (colonne "age_labels") du dataframe titanic_survival.
# - Assigner l'objet Series résultant à la variable age_group_survival.
# - Afficher le résultat.

titanic_survival["age_labels"] = age_labels
age_group_survival = titanic_survival.pivot_table(index="age_labels", values="survived")
print(age_group_survival)
# Out:
#             survived
# age_labels
# adult       0.387892
# minor       0.525974
# un          0.277567

# %%
import pandas as pd

food_info = pd.read_csv("food_info.csv")
col_names = food_info.columns.tolist()

# %%
print(col_names)
# Out:
# ['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)', 'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)', 'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)', 'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)', 'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)', 'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)', 'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)', 'Vit_D_mcg', 'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)', 'FA_Mono_(g)', 'FA_Poly_(g)', 'Cholestrl_(mg)']

# %%
food_info.head(3)
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 0    2499.0      684.0        2.32        1.5      60.0          7.0
# 1    2499.0      684.0        2.32        1.5      60.0          7.0
# 2    3069.0      840.0        2.80        1.8      73.0          8.6
#
#    FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# ...

# %%
#transformer une colonne

# / UNE COL

sodium_grams = food_info["Sodium_(mg)"] / 1000
sugar_milligrams = food_info["Sugar_Tot_(g)"] * 1000

# %%
# operation math entre colonne:diviser,additionner,afficher
grams_of_protein_per_gram_of_water = food_info["Protein_(g)"]/ food_info["Water_(g)"]
milligrams_of_calcium_and_iron = food_info["Calcium_(mg)"] + food_info["Iron_(mg)"]

# %%
print(grams_of_protein_per_gram_of_water)
# Out:
# 0       0.053560
# 1       0.053560
# 2       1.166667
# 3       0.504598
# 4       0.565313
#           ...
# 8613    0.430233
# 8614    0.292384
# 8615    0.000000
# 8616    0.203283
# 8617    0.252229
# Length: 8618, dtype: float64

# %%
# creer un indice nutrintonnel
# protein = food_info["Protein_(g)"] * 2
# fat = food_info["Lipid_Tot_(g)"] * (0.75)
# rating = protein_fat

# %%
normalized_protein = food_info["Protein_(g)"] / food_info["Protein_(g)"].max()
normalized_fat = food_info["Lipid_Tot_(g)"] / food_info["Lipid_Tot_(g)"].max()

# %%
print(normalized_fat)
# Out:
# 0       0.8111
# 1       0.8111
# 2       0.9948
# 3       0.2874
# 4       0.2968
#          ...
# 8613    0.2510
# 8614    0.0084
# 8615    0.0000
# 8616    0.0140
# 8617    0.0050
# Name: Lipid_Tot_(g), Length: 8618, dtype: float64

# %%
# normaliser une variable c'est la / par sa valeur MAX

# %%
# CREER 1 NOUVELLE COLONNE
food_info["Normalized_Protein"]=normalized_protein
food_info["Normalized_Fat"] = normalized_fat

# %%
food_info.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
# ...

# %%
food_info["Norm_Nutr_Index"] = 2 * food_info["Normalized_Protein"] + (-0.75)* food_info["Normalized_Fat"]

# %%
food_info.sort_values("Norm_Nutr_Index", inplace=True, ascending= True)
food_info
#je remplace celui qui existait
# Trier un Dataframe 
# remplacer le dataframe food_info en triant par rapport à la colonne 
#Norm_Nutr_Index de façon decroissante(du+ grand au plus petit)
# Out:
#       NDB_No                                         Shrt_Desc  Water_(g)  \
# 637     4055                                          OIL PALM       0.00
# 631     4037                                     OIL RICE BRAN       0.00
# 704     4592                      FISH OIL MENHADEN FULLY HYDR       0.00
# 638     4058                       OIL SESAME SALAD OR COOKING       0.00
# 636     4053                        OIL OLIVE SALAD OR COOKING       0.00
# ...      ...                                               ...        ...
# 8152   35055  SEAL BEARDED (OOGRUK) MEAT DRIED (ALASKA NATIVE)      11.60
# 124     1136        EGG WHITE DRIED PDR STABILIZED GLUCOSE RED       8.54
# 216     1258            EGG WHITE DRIED STABILIZED GLUCOSE RED       6.53
# 6155   19177                          GELATINS DRY PDR UNSWTND      13.00
# 4991   16423          SOY PROT ISOLATE K TYPE CRUDE PROT BASIS       4.98
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# ...
