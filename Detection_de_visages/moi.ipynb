# %%
import cv2
import numpy as np

# %%
face_cascade = cv2.CascadeClassifier('Detection de visages/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('Detection de visages/haarcascade_eye.xml')

# %%
img = cv2.imread('Detection de visages/dan.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.1, 8)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.subplot(111)
plt.imshow(img)
plt.title("photo !!! ")
plt.axis('off');

# %%
faces = face_cascade.detectMultiScale(gray, 1.1, 8)

# %%
import sys

if faces.size/4 != 2:
    print('la photo doit contenir exactement deux tetes')
    sys.exit("la photo doit contenir exactement deux tetes") 
else:
    i = 0
    for face in faces:
        x, y, w, h = face
        # dessiner le rectangle sur l'image principale
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
# affiche l'image principale
cv2.imshow('image principale', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# la photo doit contenir exactement deux tetes
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: la photo doit contenir exactement deux tetes
# /home/simplon/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
faces
# Out:
# array([[ 61,  56, 123, 123]], dtype=int32)

# %%
# affichage des visages
for face in faces:
    x, y, w, h = face
    
    # dessiner le rectangle sur l'image principale
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
import matplotlib.pyplot as plt

img = cv2.imread('Detection de visages/obama.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(10,5))
plt.subplot(111)
plt.imshow(img)
plt.title("Photo de Dan")
plt.axis('off');

faces = face_cascade.detectMultiScale(gray, 1.1, 8)

# %%
faces
# Out:
# array([[102,  37,  73,  73],
#        [236,  55,  65,  65]], dtype=int32)

# %%
photo1 = faces[0]
photo2 = faces[1]

# %%
#affichage des visages

for face in faces:
    x, y, w, h = face
        # dessiner le rectangle sur l'image principale
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    x1,y1,w1,h1 = faces[0]
    x2,y2,w2,h2 = faces[1]

    face1 = img[y1:y1+h1, x1:x1+w1]
    face2 = img[y2:y2+h2, x2:x2+w2]

    face1 = cv2.resize(face1, (w2,h2), interpolation= cv2.INTER_LINEAR)
    face2 = cv2.resize(face2, (w1,h1), interpolation= cv2.INTER_LINEAR)

    img[y1:y1+h1, x1:x1+w1] = face2
    img[y2:y2+h2, x2:x2+w2] = face1
    
    # affiche l'image principale
    cv2.imshow('image principale', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# %pwd
# Out:
# '/home/simplon/Documents/simplon/brief projet/Detection_de_visages'
