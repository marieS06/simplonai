# %%
import numpy as np

world_alcohol = np.genfromtxt("world_alcohol.csv",delimiter=",", dtype="U75", skip_header=1)
print(world_alcohol)
# Out:
# [['1986' 'Western Pacific' 'Viet Nam' 'Wine' '0']
#  ['1986' 'Americas' 'Uruguay' 'Other' '0.5']
#  ['1985' 'Africa' "Cte d'Ivoire" 'Wine' '1.62']
#  ...
#  ['1986' 'Europe' 'Switzerland' 'Spirits' '2.54']
#  ['1987' 'Western Pacific' 'Papua New Guinea' 'Other' '0']
#  ['1986' 'Africa' 'Swaziland' 'Other' '5.15']]

# %%
countries_is_canada = world_alcohol[:,2] == "canada" #quels sont les lignes qui contiennent
print(countries_is_canada)
# Out:
# [False False False ... False False False]

# %%
countries_canada = world_alcohol[world_alcohol[:,2] == "Canada"] #quels sont les lignes qui contiennent
print(countries_canada)
# Out:
# [['1984' 'Americas' 'Canada' 'Spirits' '3.35']
#  ['1989' 'Americas' 'Canada' 'Wine' '1.27']
#  ['1984' 'Americas' 'Canada' 'Beer' '5']
#  ['1985' 'Americas' 'Canada' 'Beer' '4.94']
#  ['1987' 'Americas' 'Canada' 'Wine' '1.3']
#  ['1987' 'Americas' 'Canada' 'Beer' '4.83']
#  ['1986' 'Americas' 'Canada' 'Other' '']
#  ['1986' 'Americas' 'Canada' 'Spirits' '3.11']
#  ['1985' 'Americas' 'Canada' 'Spirits' '3.21']
#  ['1985' 'Americas' 'Canada' 'Other' '']
#  ['1986' 'Americas' 'Canada' 'Beer' '4.87']
#  ['1984' 'Americas' 'Canada' 'Wine' '1.24']
#  ['1989' 'Americas' 'Canada' 'Spirits' '2.91']
#  ['1984' 'Americas' 'Canada' 'Other' '']
#  ['1985' 'Americas' 'Canada' 'Wine' '1.29']
#  ['1987' 'Americas' 'Canada' 'Spirits' '2.99']
#  ['1989' 'Americas' 'Canada' 'Beer' '4.82']
#  ['1989' 'Americas' 'Canada' 'Other' '']
#  ['1986' 'Americas' 'Canada' 'Wine' '1.33']
#  ['1987' 'Americas' 'Canada' 'Other' '']]

# %%
countries_is_algeria = world_alcohol[:,2] == "Algeria" #quels sont les lignes qui contiennent

print(countries_is_algeria)
# Out:
# [False False False ... False False False]

# %%
countries_is_algeria = world_alcohol[world_alcohol[:,2] == "Algeria"]
print(countries_is_algeria)
# Out:
# [['1984' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1987' 'Africa' 'Algeria' 'Beer' '0.17']
#  ['1987' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1986' 'Africa' 'Algeria' 'Wine' '0.1']
#  ['1984' 'Africa' 'Algeria' 'Other' '0']
#  ['1989' 'Africa' 'Algeria' 'Beer' '0.16']
#  ['1989' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1989' 'Africa' 'Algeria' 'Wine' '0.23']
#  ['1986' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1984' 'Africa' 'Algeria' 'Wine' '0.12']
#  ['1985' 'Africa' 'Algeria' 'Beer' '0.19']
#  ['1985' 'Africa' 'Algeria' 'Other' '0']
#  ['1986' 'Africa' 'Algeria' 'Beer' '0.18']
#  ['1985' 'Africa' 'Algeria' 'Wine' '0.11']
#  ['1986' 'Africa' 'Algeria' 'Other' '0']
#  ['1989' 'Africa' 'Algeria' 'Other' '0']
#  ['1987' 'Africa' 'Algeria' 'Other' '0']
#  ['1984' 'Africa' 'Algeria' 'Beer' '0.2']
#  ['1985' 'Africa' 'Algeria' 'Spirits' '0.01']
#  ['1987' 'Africa' 'Algeria' 'Wine' '0.1']]

# %%
print(world_alcohol[:,0][world_alcohol[:,0] == '1986'])
# Out:
# ['1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
#  '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986' '1986'
# ...

# %%
is_value_empty = (world_alcohol [:,4] == '') #lig,col
print(is_value_empty) # quand c'est vide
# Out:
# [False False False ... False False False]

# %%
# on rajoute ---------------pour ttes les col vide on raj 0
world_alcohol[is_value_empty, 4] = '0'
print(world_alcohol)
# Out:
# [['1986' 'Western Pacific' 'Viet Nam' 'Wine' '0']
#  ['1986' 'Americas' 'Uruguay' 'Other' '0.5']
#  ['1985' 'Africa' "Cte d'Ivoire" 'Wine' '1.62']
#  ...
#  ['1986' 'Europe' 'Switzerland' 'Spirits' '2.54']
#  ['1987' 'Western Pacific' 'Papua New Guinea' 'Other' '0']
#  ['1986' 'Africa' 'Swaziland' 'Other' '5.15']]

# %%
alcohol_consumption = world_alcohol[:,4] # je recup
alcohol_consumption = alcohol_consumption.astype(float) # pour convertir
print(alcohol_consumption)
# Out:
# [0.   0.5  1.62 ... 2.54 0.   5.15]

# %%
#Trouver le pays qui consomme le plus d'alcool. -

#Créer une variable highest_value qui gardera en mémoire la plus grande valeur du dictionnaire totals. 
#On la fixe à 0 pour commencer. - Créer une variable similaire qu'on nommera highest_key qui gardera en mémoire 
#le nom du pays associé à la plus grande valeur. On la fixe à la valeur None. 
#- Parcourir chaque pays du dictionnaire totals: >- Si la valeur associée au pays 
#est plus grande que highest_value, assigner la valeur en question à la variable highest_value
#et assigner la clé correspondante (nom du pays) à la variable highest_key. - 
#Afficher le pays qui consomme le plus d'alcool (variable highest_key) Puis ensuite créer une fonction qui aura 
#pour argument d'entré une année et retournera le dictionnaire contenant la consommation moyenne pour chaque pays.


highest_value = 0
highest_key = None

for index,info in enumerate(world_alcohol[1:]):
    value = np.float(info[-1])
    if(highest_value<value):
        highest_key = index+1
        highest_value=value
print(world_alcohol[highest_key])
# Out:
# ['1984' 'Europe' 'Portugal' 'Wine' '13.5']

# %%
def mean_alc_per_year(year, data=world_alcohol):
   
    dico = {}
    compteur = {}
    test = []
    for info in my_data[1:]:    
        if info[0] == year : # on selectionne l'anne
            nom_pays = info[2]
            value = np.float(info[-1])
            # on verifie qu'il y a une valeur
            if np.isnan(value):
                value = 0
            # on test si le pays a deja une valeur
            if(nom_pays in dico ):
                dico[nom_pays] += value
                compteur[nom_pays] += 1
            else:
                dico[nom_pays] = value
                compteur[nom_pays] = 1
               
            test.append(nom_pays)
    # on calcul la moyenne
   
    resultat = {}
    for pays in test:
        val = dico[pays]
        cpt = compteur[pays]
        print(pays, val,cpt)
        resultat[pays] = val/cpt
    return resultat

# %%
my_data = world_alcohol

# %%
def mean_alc_per_year(year, data=world_alcohol):
    
    dico = {}
    compteur = {}
    test = []
    for info in my_data[1:]:
        if info[0] == year :
            nom_pays = info[2]
            value = np.float(info[-1])
            if np.isnan(value):
                value = 0
            if(nom_pays in dico):
                dico[nom_pays] += value
                compteur[nom_pays] += 1
            else:
                dico[nom_pays] = value
                compteur[nom_pays] = 1
            
            test.append(nom_pays)
            
    resultat = {}
    for pays in test:
        val = dico[pays]
        cpt = compteur[pays]
        print(pays, val,cpt)
        resultat[pays] = val/cpt
    return resultat
    
resultat=mean_alc_per_year('1986')

print(resultat)
# Out:
# Uruguay 7.2299999999999995 4
# Colombia 6.609999999999999 4
# Antigua and Barbuda 3.55 4
# Myanmar 0.28 4
# Italy 12.3 4
# Sierra Leone 4.61 4
# Micronesia (Federated States of) 0.0 4
# Russian Federation 5.289999999999999 4
# Sweden 7.210000000000001 4
# Czech Republic 13.01 4
# Mexico 4.430000000000001 4
# Malta 5.34 4
# Saudi Arabia 0.2 4
# Togo 2.8 4
# Madagascar 1.4 4
# Pakistan 0.02 4
# Bolivia (Plurinational State of) 3.29 4
# Ukraine 4.390000000000001 4
# Sri Lanka 0.19 4
# Bahamas 14.120000000000001 4
# Lebanon 4.12 4
# Eritrea 0.3 4
# Spain 14.370000000000001 4
# Madagascar 1.4 4
# Gambia 2.19 4
# Nicaragua 3.48 4
# Belgium 12.72 4
# Bolivia (Plurinational State of) 3.29 4
# Zambia 3.07 4
# Gambia 2.19 4
# Uganda 7.47 4
# Cabo Verde 2.92 4
# Saint Kitts and Nevis 3.98 4
# Norway 5.27 4
# Australia 12.3 4
# Togo 2.8 4
# Venezuela (Bolivarian Republic of) 8.32 4
# Cyprus 8.32 4
# Vanuatu 1.74 4
# Syrian Arab Republic 1.02 4
# Bhutan 0.46 4
# Guinea 0.16000000000000003 4
# ...
