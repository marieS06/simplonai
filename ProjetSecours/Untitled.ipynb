# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('caracteristiques_weekdaytime.csv')

da = pd.read_csv('usagers-2019.csv', delimiter=";")

# %%
data
# Out:
#        Unnamed: 0       Num_Acc  jour  mois    an   hrmn  lum dep    com  agg  \
# 0               0  201900000001    30    11  2019  01:30    4  93  93053    1
# 1               1  201900000002    30    11  2019  02:50    3  93  93066    1
# 2               2  201900000003    28    11  2019  15:15    1  92  92036    1
# 3               3  201900000004    30    11  2019  20:20    5  94  94069    1
# 4               4  201900000005    30    11  2019  04:00    3  94  94028    1
# ...           ...           ...   ...   ...   ...    ...  ...  ..    ...  ...
# 58835       58835  201900058836    30    11  2019  09:00    1  69  69288    1
# 58836       58836  201900058837    27    11  2019  07:50    1  67  67482    1
# 58837       58837  201900058838    30    11  2019  02:41    4  94  94021    1
# 58838       58838  201900058839    30    11  2019  15:20    1  78  78640    1
# 58839       58839  201900058840    29    11  2019  20:50    3  92  92047    1
#
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Num_Acc         int64
# jour            int64
# mois            int64
# an              int64
# hrmn           object
# lum             int64
# dep            object
# com            object
# agg             int64
# int             int64
# atm             int64
# col             int64
# adr            object
# lat            object
# long           object
# weekday         int64
# time          float64
# dtype: object

# %%
data.sum().isnull()
# Out:
# <ipython-input-67-eb8aa579eb39>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.sum().isnull()
# Unnamed: 0    False
# Num_Acc       False
# jour          False
# mois          False
# an            False
# hrmn          False
# lum           False
# dep           False
# com           False
# agg           False
# int           False
# atm           False
# col           False
# lat           False
# long          False
# weekday       False
# time          False
# dtype: bool

# %%
merged_df=data.merge(da)

# %%
merged_df
# Out:
#         Unnamed: 0       Num_Acc  jour  mois    an   hrmn  lum dep    com  \
# 0                0  201900000001    30    11  2019  01:30    4  93  93053
# 1                0  201900000001    30    11  2019  01:30    4  93  93053
# 2                0  201900000001    30    11  2019  01:30    4  93  93053
# 3                1  201900000002    30    11  2019  02:50    3  93  93066
# 4                2  201900000003    28    11  2019  15:15    1  92  92036
# ...            ...           ...   ...   ...   ...    ...  ...  ..    ...
# 132972       58836  201900058837    27    11  2019  07:50    1  67  67482
# 132973       58837  201900058838    30    11  2019  02:41    4  94  94021
# 132974       58838  201900058839    30    11  2019  15:20    1  78  78640
# 132975       58839  201900058840    29    11  2019  20:50    3  92  92047
# 132976       58839  201900058840    29    11  2019  20:50    3  92  92047
#
#         agg  ...  grav  sexe  an_nais trajet secu1 secu2  secu3  locp actp  \
# ...

# %%
merged_df=merged_df.drop(columns=['Unnamed: 0','int','col','sexe','com','adr','lat','long','id_vehicule','num_veh','place','an_nais', 'trajet', 'secu1', 'secu2', 'secu3', 'locp', 'actp','etatp','catu'])

# %%
merged_df
# Out:
#              Num_Acc  jour  mois    an   hrmn  lum dep  agg  atm  weekday  \
# 0       201900000001    30    11  2019  01:30    4  93    1    1        5
# 1       201900000001    30    11  2019  01:30    4  93    1    1        5
# 2       201900000001    30    11  2019  01:30    4  93    1    1        5
# 3       201900000002    30    11  2019  02:50    3  93    1    1        5
# 4       201900000003    28    11  2019  15:15    1  92    1    1        3
# ...              ...   ...   ...   ...    ...  ...  ..  ...  ...      ...
# 132972  201900058837    27    11  2019  07:50    1  67    1    8        2
# 132973  201900058838    30    11  2019  02:41    4  94    1    1        5
# 132974  201900058839    30    11  2019  15:20    1  78    1    1        5
# 132975  201900058840    29    11  2019  20:50    3  92    1    1        4
# 132976  201900058840    29    11  2019  20:50    3  92    1    1        4
#
#              time  grav
# 0        1.500000     4
# 1        1.500000     4
# ...

# %%
merged_df=merged_df[merged_df['atm']!= -1]

# %%
merged_df.describe()
# Out:
#             Num_Acc           jour           mois        an            lum  \
# count  1.329760e+05  132976.000000  132976.000000  132976.0  132976.000000
# mean   2.019000e+11      15.679491       6.701578    2019.0       1.932717
# std    1.699437e+04       8.746316       3.385588       0.0       1.495198
# min    2.019000e+11       1.000000       1.000000    2019.0       1.000000
# 25%    2.019000e+11       8.000000       4.000000    2019.0       1.000000
# 50%    2.019000e+11      16.000000       7.000000    2019.0       1.000000
# 75%    2.019000e+11      23.000000      10.000000    2019.0       3.000000
# max    2.019001e+11      31.000000      12.000000    2019.0       5.000000
#
#                  agg            atm        weekday           time  \
# count  132976.000000  132976.000000  132976.000000  132976.000000
# mean        1.622594       1.614299       3.015920      13.959742
# std         0.484740       1.672976       1.948626       5.482366
# ...

# %%
merged_df
# Out:
#              Num_Acc  jour  mois    an   hrmn  lum dep  agg  atm  weekday  \
# 0       201900000001    30    11  2019  01:30    4  93    1    1        5
# 1       201900000001    30    11  2019  01:30    4  93    1    1        5
# 2       201900000001    30    11  2019  01:30    4  93    1    1        5
# 3       201900000002    30    11  2019  02:50    3  93    1    1        5
# 4       201900000003    28    11  2019  15:15    1  92    1    1        3
# ...              ...   ...   ...   ...    ...  ...  ..  ...  ...      ...
# 132972  201900058837    27    11  2019  07:50    1  67    1    8        2
# 132973  201900058838    30    11  2019  02:41    4  94    1    1        5
# 132974  201900058839    30    11  2019  15:20    1  78    1    1        5
# 132975  201900058840    29    11  2019  20:50    3  92    1    1        4
# 132976  201900058840    29    11  2019  20:50    3  92    1    1        4
#
#              time  grav
# 0        1.500000     4
# 1        1.500000     4
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


sns.pairplot(merged_df)

# %%
merged_df.corr()
# Out:
#           Num_Acc      jour      mois  an       lum       agg       atm  \
# Num_Acc  1.000000  0.013924 -0.099603 NaN -0.002873  0.008230 -0.001167
# jour     0.013924  1.000000 -0.023670 NaN -0.001444 -0.009481 -0.026876
# mois    -0.099603 -0.023670  1.000000 NaN  0.072128 -0.014666  0.047140
# an            NaN       NaN       NaN NaN       NaN       NaN       NaN
# lum     -0.002873 -0.001444  0.072128 NaN  1.000000  0.107352  0.011936
# agg      0.008230 -0.009481 -0.014666 NaN  0.107352  1.000000 -0.023765
# atm     -0.001167 -0.026876  0.047140 NaN  0.011936 -0.023765  1.000000
# weekday  0.019622  0.024316 -0.005442 NaN  0.092229 -0.079392  0.001270
# time    -0.008619  0.010633  0.000127 NaN  0.061338  0.033034 -0.023843
# grav    -0.000463 -0.002213  0.003623 NaN  0.033349 -0.006402  0.001138
#
#           weekday      time      grav
# Num_Acc  0.019622 -0.008619 -0.000463
# jour     0.024316  0.010633 -0.002213
# mois    -0.005442  0.000127  0.003623
# ...

# %%
merged_df['grav'].unique()
# Out:
# array([4, 1, 3, 2])

# %%
#import numpy as np

#merged_df["grav"] = pd.cut(merged_df["grav"],
 #                              bins=4,
  #                             labels=["1", "2",
   #                                    "3", "4"])

# %%
merged_df
# Out:
#              Num_Acc  jour  mois    an   hrmn  lum dep  agg  atm  weekday  \
# 0       201900000001    30    11  2019  01:30    4  93    1    1        5
# 1       201900000001    30    11  2019  01:30    4  93    1    1        5
# 2       201900000001    30    11  2019  01:30    4  93    1    1        5
# 3       201900000002    30    11  2019  02:50    3  93    1    1        5
# 4       201900000003    28    11  2019  15:15    1  92    1    1        3
# ...              ...   ...   ...   ...    ...  ...  ..  ...  ...      ...
# 132972  201900058837    27    11  2019  07:50    1  67    1    8        2
# 132973  201900058838    30    11  2019  02:41    4  94    1    1        5
# 132974  201900058839    30    11  2019  15:20    1  78    1    1        5
# 132975  201900058840    29    11  2019  20:50    3  92    1    1        4
# 132976  201900058840    29    11  2019  20:50    3  92    1    1        4
#
#              time  grav
# 0        1.500000     4
# 1        1.500000     4
# ...

# %%
#cont = merged_df[["grav", "time"]].pivot_table(
 #   index="grav", columns="time", aggfunc=len).fillna(0).copy().astype(int)

#cont

# %%
#from scipy.stats import chi2_contingency
#st_chi2, st_p, st_dof, st_exp = chi2_contingency(cont)
#st_p

# %%
#import numpy as np
#from sklearn.model_selection import StratifiedShuffleSplit

#X = merged_df[['jour','mois','an','lum','agg','atm','weekday']]
  
#y = merged_df['grav']

#sss = StratifiedShuffleSplit(n_splits=5, test_size=0.5, random_state=0)
#sss.get_n_splits(X, y)

#print(sss)
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import SGDClassifier, SGDRegressor
from sklearn.metrics import accuracy_score

# %%
cat_attribs = ['jour','agg','atm','weekday']

full_pipeline3 = ColumnTransformer([

    ("cat", OneHotEncoder(), cat_attribs),
])

# %%
def learning(full_pipeline):
    ac_score = []
    
    skf = StratifiedKFold(n_splits=100)
    
    for train_index, test_index in skf.split(data, data['grav']):
        
        data_train, data_test = data.loc[train_index], data.loc[test_index]
        
        X_train = full_pipeline.fit_transform(data_train)
        y_train = np.array(data_train['grav'])
        
        X_test = full_pipeline.transform(data_test)
        y_test = np.array(data_test['grav'])
        
        model = SGDClassifier(max_iter=1000, loss="hinge")
        model.fit(X_train, y_train)
        ac_score.append(accuracy_score(y_test, model.predict(X_test)))
        
    print("------------------")
    print("Prediction moyenne :", np.mean(ac_score))
    return np.mean(ac_score)

# %%
learning(full_pipeline1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-a6abf965bcd3> in <module>
# ----> 1 learning(full_pipeline1)
#
# <ipython-input-82-86a8aa8798da> in learning(full_pipeline)
#      15
#      16         model = SGDClassifier(max_iter=1000, loss="hinge")
# ---> 17         model.fit(X_train, y_train)
#      18         ac_score.append(accuracy_score(y_test, model.predict(X_test)))
#      19
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py in fit(self, X, y, coef_init, intercept_init, sample_weight)
#     727             Returns an instance of self.
#     728         """
# --> 729         return self._fit(X, y, alpha=self.alpha, C=1.0,
#     730                          loss=self.loss, learning_rate=self.learning_rate,
#     731                          coef_init=coef_init, intercept_init=intercept_init,
#
# ...

# %%
learning(full_pipeline2)
# Out:
# ------------------
# Prediction moyenne : 0.033139617476871906
# 0.033139617476871906

# %%
learning(full_pipeline3)
# Out:
# ------------------
# Prediction moyenne : 1.0
# 1.0

# %%
X = full_pipeline3.fit_transform(data)
y = np.array(data["grav"])

model = SGDRegressor(max_iter=1000, loss='hinge')
model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-e1ab945a2436> in <module>
#       2 y = np.array(data["atm"])
#       3
# ----> 4 model = SGDRegressor(max_iter=1000, loss='hinge')
#       5 model.fit(X,y)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py in __init__(self, loss, penalty, alpha, l1_ratio, fit_intercept, max_iter, tol, shuffle, verbose, epsilon, random_state, learning_rate, eta0, power_t, early_stopping, validation_fraction, n_iter_no_change, warm_start, average)
# ...

# %%
X = full_pipeline1.fit_transform(data)
y = np.array(data["atm"])

model = SGDRegressor(max_iter=1000, loss='hinge')
model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-1be7715429ce> in <module>
#       2 y = np.array(data["atm"])
#       3
# ----> 4 model = SGDRegressor(max_iter=1000, loss='hinge')
#       5 model.fit(X,y)
#
# NameError: name 'SGDRegressor' is not defined

# %%
from matplotlib.colors import ListedColormap

X = full_pipeline1.transform(data)
X1 = np.arange(start = X[:,0].min() -1, stop = X[:,0].max() + 1, step = 0.01)
X2 = np.arange(start = X[:,1].min() -1, stop = X[:,1].max() + 1, step = 0.01)
X3 = np.arange(start = X[:,2].min() -1, stop = X[:,2].max() + 1, step = 0.01)

X1, X2, X3 = np.meshgrid(X1,X2,X3)

Z = model.predict(np.array([X1.ravel(), X2.ravel(), X3.ravel()]).T).reshape(X1.shape)
                 
#plt.contourf(X1, X2, X3, Z,
            #alpha = 0.4, cmap = ListedColormap(('red', 'green','pink')));
                 
for i, j in enumerate(np.unique(y)):
    plt.scatter(X[y == j, 0], X[y == j, 1],
               c = ListedColormap(('white','red', 'green'))(i), label = j)
                  
plt.title('client fidèles')
plt.xlabel('age')
plt.ylabel('durée')

plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
merged_df.dtypes
# Out:
# Num_Acc      int64
# jour         int64
# mois         int64
# an           int64
# hrmn        object
# lum          int64
# dep         object
# agg          int64
# atm          int64
# weekday      int64
# time       float64
# grav         int64
# dtype: object

# %%
from sklearn.kernel_approximation import PolynomialCountSketch, RBFSampler


num_attribs = []
cat_attribs = ["jour","atm", "lum", "an", "weekday"]

num_pipeline1 = Pipeline([
        ('std_scaler', StandardScaler()),
        ('poly', PolynomialCountSketch(degree=5))
    ])

num_pipeline2 = Pipeline([
        ('std_scaler', StandardScaler()),
        ('RBFGaussian', RBFSampler(gamma=0.5))
    ])


full_pipeline1 = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
    ])

full_pipeline2 = ColumnTransformer([
        ("num", num_pipeline2, num_attribs),
    ])

# %%
learning(full_pipeline1)
# Out:
# ------------------
# Prediction moyenne : 0.027871146760911493
# 0.027871146760911493

# %%
learning(full_pipeline2)
# Out:
# ------------------
# Prediction moyenne : 0.033905558827945444
# 0.033905558827945444

# %%
X = full_pipeline2.fit_transform(data)
y = np.array(data["jour"])

model = SGDClassifier(max_iter=1000, loss='hinge')
model.fit(X, y)
# Out:
# SGDClassifier()

# %%
data.dtypes

# %%
import os
import numpy as np

from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

count_vec = CountVectorizer()
X = count_vec.fit_transform(X_train)
print(X_train_counts)
# Out:
#   (0, 5)	1
#   (1, 7)	1
#   (2, 1)	1
#   (3, 4)	1
#   (4, 6)	1
#   (5, 3)	1
#   (6, 0)	1
#   (7, 2)	1
#   (8, 9)	1
#   (9, 8)	1

# %%
count_vec.vocabulary_
# Out:
# {'jour': 5,
#  'mois': 7,
#  'an': 1,
#  'hrmn': 4,
#  'lum': 6,
#  'dep': 3,
#  'agg': 0,
#  'atm': 2,
#  'weekday': 9,
#  'time': 8}

# %%
X_train_counts.shape
# Out:
# (10, 10)

# %%
print(X_train_counts[0])
# Out:
#   (0, 5)	1

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf[0])
# Out:
#   (0, 5)	1.0

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB

model = BernoulliNB()
model.fit(X_train_tfidf, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-332-6a0928ea6776> in <module>
#       2
#       3 model = BernoulliNB()
# ----> 4 model.fit(X_train_tfidf, y_train)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     610         self : object
#     611         """
# --> 612         X, y = self._check_X_y(X, y)
#     613         _, n_features = X.shape
#     614         self.n_features_ = n_features
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in _check_X_y(self, X, y)
#    1017
#    1018     def _check_X_y(self, X, y):
# -> 1019         X, y = super()._check_X_y(X, y)
#    1020         if self.binarize is not None:
#    1021             X = binarize(X, threshold=self.binarize)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in _check_X_y(self, X, y)
#     475
# ...

# %%
X_test_counts = count_vec.transform(X_test)
X_test_tfidf = tfidf_transformer.transform(X_test_counts)
y_pred = model.predict(X_test_tfidf)

print(accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-273-d0b2211a9133> in <module>
#       1 X_test_counts = count_vec.transform(X_test)
#       2 X_test_tfidf = tfidf_transformer.transform(X_test_counts)
# ----> 3 y_pred = model.predict(X_test_tfidf)
#       4
#       5 print(accuracy_score(y_test, y_pred))
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in predict(self, X)
#      71             Predicted target values for X
#      72         """
# ---> 73         check_is_fitted(self)
#      74         X = self._check_X(X)
#      75         jll = self._joint_log_likelihood(X)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
# ...
