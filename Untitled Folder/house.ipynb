# %%
import pandas as pd
c = pd.read_csv('housing.csv')

# %%
c
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
b = c['longitude']
v = sum(b.isnull())
v
# Out:
# 0

# %%
e = c['latitude']
i = sum(e)
print(i)
# Out:
# 735441.6200000036

# %%
taille = c['longitude'] + c['latitude'] 
ll = c['median_house_value']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# je test un deuxieme modele

# %%
X = np.c_[c[["longitude", "latitude"]]]
Y = np.array(c["median_house_value"])

X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, random_state=0)

X_valid, X_test, y_valid, y_test = train_test_split(
        X_test, y_test, test_size=0.5)

model = make_pipeline(StandardScaler(),
                     SGDRegressor(max_iter=1000, alpha=0.0001))
#model = sklearn.linear_model.SGDRegressor()

# Train the model
model.fit(X_train, y_train)

metric2 = {'modele': 'model 2',
          'mean_absolute_error': mean_absolute_error(y_valid, model.predict(X_valid)),
          'mean_squared_error': mean_squared_error(y_valid, model.predict(X_valid)),
          'r2_score':r2_score(y_valid, model.predict(X_valid))
         }

print(metric2)
# Out:
# {'modele': 'model 2', 'mean_absolute_error': 76678.61244353837, 'mean_squared_error': 10009600253.820436, 'r2_score': 0.24679504955057585}

# %%
sns.set(style="white", color_codes=True)
sns.pairplot(data=c)
plt.show()

# %%
correlation = c.corr()
plt.figure()
plt.subplot(111)
sns.heatmap(correlation, annot=True, linewidths=1.0)
plt.show()

# %%
# Code example
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model
from sklearn.model_selection import train_test_split # separer le jeux de donnees



# Prepare the data
X = np.c_[c["longitude"]]
y = np.c_[c["latitude"]]
# train_test_split 2 entree la 2 y contienr ma var cible 
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, random_state=0)
#2 decoupage x et x contiennent 40% de donnees 
X_valid, X_test, y_valid, y_test = train_test_split(
        X_test, y_test, test_size=0.5)

print(X.shape, y.shape)

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)

# Visualize the data
c.plot(kind='scatter', x="longitude", y='latitude')
plt.show()

# Select a linear model
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X_train, y_train)
# fit entrainement 2 quelle est la var à predire

# Make a prediction for Cyprus
X_new = [[22587]]  # Cyprus' GDP per capita
# X majuscule si contient plusieurs variable
print(model.predict(X_new)) # outputs [[ 5.96242338]]
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# (20640, 1) (20640, 1)
# (12384, 1) (12384, 1)
# (4128, 1) (4128, 1)
# (4128, 1) (4128, 1)
# [[-22342.84277115]]

# %%
from sklearn.metrics import mean_absolute_error
# 
y_true = y_test
y_pred =model.predict(X_test)
print(model.predict(X_test))
print(mean_absolute_error(y_true, y_pred))
# Out:
# [[35.69001441]
#  [37.60198257]
#  [38.17360192]
#  ...
#  [35.63088137]
#  [34.37923211]
#  [34.10327795]]
# 0.6184709041266382

# %%
from sklearn.metrics import mean_absolute_error
y_true = y_valid
y_pred =model.predict(X_valid)
print(model.predict(X_test))
print(mean_absolute_error(y_true, y_pred))
# Out:
# [[35.69001441]
#  [37.60198257]
#  [38.17360192]
#  ...
#  [35.63088137]
#  [34.37923211]
#  [34.10327795]]
# 0.6220545461289887

# %%
from sklearn.metrics import mean_squared_error
y_true = y_test
y_pred = model.predict(X_test)
mean_squared_error(y_true, y_pred)
# Out:
# 0.6770661145473672

# %%
from sklearn.metrics import mean_squared_error
y_true = y_valid
y_pred = model.predict(X_valid)
mean_squared_error(y_true, y_pred)
# Out:
# 0.6683901669459067

# %%
from sklearn.metrics import r2_score
y_true = y_test
y_pred = model.predict(X_test)
r2_score(y_true, y_pred)
# Out:
# 0.851027077882369

# %%
from sklearn.metrics import r2_score
y_true = y_valid
y_pred = model.predict(X_valid)
r2_score(y_true, y_pred)
# Out:
# 0.8535317325042089

# %%
#ocean = c['ocean_proximity']
#ocean.astype('string').dtypes
# Out:
# StringDtype

# %%
#ocean = c['ocean_proximity']
#ocean.astype('string').dtypes

# %%
ocean
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20640, dtype: object

# %%
X = np.c_[c[["longitude", "latitude"]]]
y = np.array(c["median_house_value"])

X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4)

X_valid, X_test, y_valid, y_test = train_test_split(
        X_test, y_test, test_size=0.5)

# Select a linear model
model = make_pipeline(StandardScaler(),
                     SGDRegressor(max_iter=1000, alpha=0.0001))
#model = sklearn.linear_model.SGDRegressor()

# Train the model
model.fit(X_train, y_train)

metric3 = {'modele': 'model 3',
          'mean_absolute_error': mean_absolute_error(y_valid, model.predict(X_valid)),
          'mean_squared_error': mean_squared_error(y_valid, model.predict(X_valid)),
          'r2_score':r2_score(y_valid, model.predict(X_valid))
         }
print(metric3)
# Out:
# {'modele': 'model 3', 'mean_absolute_error': 75895.70743869108, 'mean_squared_error': 9883946437.830551, 'r2_score': 0.24471022470881554}

# %%
X = np.c_[c[["longitude", "latitude"]]]
y = np.array(c["median_house_value"])

X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, random_state=0)

X_valid, X_test, y_valid, y_test = train_test_split(
        X_test, y_test, test_size=0.5)

# Select a linear model
model = make_pipeline(StandardScaler(),
                     SGDRegressor(max_iter=1000, alpha=0.0001))
#model = sklearn.linear_model.SGDRegressor()

# Train the model
model.fit(X_train, y_train)

metric4 = {'modele': 'model 4',
          'mean_absolute_error': mean_absolute_error(y_valid, model.predict(X_valid)),
          'mean_squared_error': mean_squared_error(y_valid, model.predict(X_valid)),
          'r2_score':r2_score(y_valid, model.predict(X_valid))
         }
metric4
# Out:
# {'modele': 'model 4',
#  'mean_absolute_error': 78563.99550761728,
#  'mean_squared_error': 10366019869.834553,
#  'r2_score': 0.22839620118433313}

# %%
metric = pd.DataFrame([metric3, metric4])

# %%
metric
# Out:
#     modele  mean_absolute_error  mean_squared_error  r2_score
# 0  model 3         75895.707439        9.883946e+09  0.244710
# 1  model 4         78563.995508        1.036602e+10  0.228396

# %%
ax = sns.barplot(x="modele", y="mean_absolute_error", data=metric)

# %%
ax = sns.barplot(x="modele", y="mean_squared_error", data=metric)

# %%
ax = sns.barplot(x="modele", y="r2_score", data=metric)

# %%
from sklearn.preprocessing import PolynomialFeatures

X = np.c_[c[["longitude", "latitude"]]]
y = np.array(c["median_house_value"])

poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_features.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, random_state=0)

X_valid, X_test, y_valid, y_test = train_test_split(
        X_test, y_test, test_size=0.5)

# %%
model = make_pipeline(StandardScaler(), PolynomialFeatures(degree=2, include_bias=False),
                     SGDRegressor(max_iter=1000, alpha=0.1))

model.fit(X_train, y_train)

metric_poly2 = {'modele': 'model_ploy3',
          'mean_absolute_error': mean_absolute_error(y_valid, model.predict(X_valid)),
          'mean_squared_error': mean_squared_error(y_valid, model.predict(X_valid)),
          'r2_score':r2_score(y_valid, model.predict(X_valid))
         }

# %%
metric_poly2
# Out:
# {'modele': 'model_ploy3',
#  'mean_absolute_error': 82019.93424199308,
#  'mean_squared_error': 11338150723.59488,
#  'r2_score': 0.1702460904873464}

# %%
model = make_pipeline(StandardScaler(),
                      PolynomialFeatures(degree=4, include_bias=False),
                     SGDRegressor(max_iter=1000, alpha=0.1))

model.fit(X_train, y_train)

metric_poly3 = {'modele': 'model_ploy3',
          'mean_absolute_error': mean_absolute_error(y_valid, model.predict(X_valid)),
          'mean_squared_error': mean_squared_error(y_valid, model.predict(X_valid)),
          'r2_score':r2_score(y_valid, model.predict(X_valid))
         }

# %%
metric_poly3
# Out:
# {'modele': 'model_ploy3',
#  'mean_absolute_error': 80123.91678751622,
#  'mean_squared_error': 11032434321.58183,
#  'r2_score': 0.19261917283176977}

# %%
model = make_pipeline(StandardScaler(),
                     SGDRegressor(max_iter=1000,
                                  alpha=0.1,
                                  penalty = 'l2'))

model.fit(X_train, y_train)

metric_Ridge1 = {'modele': 'model_Ridge1',
          'mean_absolute_error': mean_absolute_error(y_valid, model.predict(X_valid)),
          'mean_squared_error': mean_squared_error(y_valid, model.predict(X_valid)),
          'r2_score':r2_score(y_valid, model.predict(X_valid))
         }

metric_Ridge1
# Out:
# {'modele': 'model_Ridge1',
#  'mean_absolute_error': 83245.23916794886,
#  'mean_squared_error': 11380007470.32655,
#  'r2_score': 0.16718291024863174}

# %%
model = make_pipeline(StandardScaler(),
                     SGDRegressor(max_iter=1000,
                                  alpha=0.1,
                                  penalty = 'l1'))

model.fit(X_train, y_train)

metric_Lasso1 = {'modele': 'model_Lasso1',
          'mean_absolute_error': mean_absolute_error(y_valid, model.predict(X_valid)),
          'mean_squared_error': mean_squared_error(y_valid, model.predict(X_valid)),
          'r2_score':r2_score(y_valid, model.predict(X_valid))
         }

metric_Lasso1
# Out:
# {'modele': 'model_Lasso1',
#  'mean_absolute_error': 77470.66428472612,
#  'mean_squared_error': 10262801340.094288,
#  'r2_score': 0.24894281774065397}

# %%
model = make_pipeline(StandardScaler(),
                     SGDRegressor(max_iter=1000,
                                  alpha=0.1,
                                  penalty = 'elasticnet',
                                  l1_ratio=0.7))

model.fit(X_train, y_train)

metric_ElasticNet1 = {'modele': 'model_ElasticNet1',
          'mean_absolute_error': mean_absolute_error(y_valid, model.predict(X_valid)),
          'mean_squared_error': mean_squared_error(y_valid, model.predict(X_valid)),
          'r2_score':r2_score(y_valid, model.predict(X_valid))
         }

metric_ElasticNet1
# Out:
# {'modele': 'model_ElasticNet1',
#  'mean_absolute_error': 78677.74365878284,
#  'mean_squared_error': 10552151892.260992,
#  'r2_score': 0.22776742876118516}
